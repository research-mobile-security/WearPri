# %%
from pymongo import MongoClient
import os
import javalang
from typing import List

# %%
def connect_mongodb(uri, db_name, collection_name):
    # Connect to MongoDB 
    client = MongoClient(uri)
    
    # Select the database and collection
    db = client[db_name]
    collection = db[collection_name]
    
    return collection
def get_third_parties_with_stop_share(collection):
    # Query to find all documents where "stop_share" is "yes"
    results = collection.find({"stop_share": "yes"}, {"third_party": 1, "_id": 0})
    third_parties = [item["third_party"] for item in results]
    return third_parties
def get_files_with_extension(directory, extension, prefix=""):
    """
    Get all files in the given directory that start with a specific prefix
    and have a specific file extension.

    Args:
        directory (str): Path to the directory.
        extension (str): File extension (e.g., '.java').
        prefix (str): Optional prefix the filename must start with (e.g., 'wrap-').

    Returns:
        list: List of full file paths matching the extension and prefix.
    """
    return [
        os.path.join(directory, f)
        for f in os.listdir(directory)
        if os.path.isfile(os.path.join(directory, f))
        and f.lower().endswith(extension.lower())
        and f.startswith(prefix)
    ]
def extract_ast_paths(code: str) -> List[str]:
    try:
        tree = javalang.parse.parse(code)
    except javalang.parser.JavaSyntaxError as e:
        print(f"Error parsing Java code: {e}")
        return []
    
    paths = []
    
    def traverse(node, path):
        if isinstance(node, javalang.ast.Node):
            node_name = type(node).__name__
            path.append(node_name)
            
            for child in node.children:
                if isinstance(child, list):
                    for item in child:
                        traverse(item, path[:])
                else:
                    traverse(child, path[:])
                    
        elif isinstance(node, list):
            for item in node:
                traverse(item, path[:])
        else:
            if node is not None:
                paths.append(".".join(path) + " -> " + str(node))
    
    traverse(tree, [])
    return paths


# Read Java from file
def read_java_code_from_file(file_path: str) -> str:
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            code = file.read()
        return code
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return ""
    except Exception as e:
        print(f"Error reading file: {e}")
        return ""
def sanitize_code(code: str) -> str:
    return (
        code
        .replace("“", "\"")
        .replace("”", "\"")
        .replace("‘", "'")
        .replace("’", "'")
    )

# %%
# server
mongoDB_uri = 'mongodb://localhost:27017'
mongoDB_database = 'wearable-project-2' 
mongoDB_collection = 'third_party_services'
# direction
root_directory = r"C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data"

# %%
# Connect to the MongoDB collection
collection = connect_mongodb(mongoDB_uri,mongoDB_database,mongoDB_collection)
third_parties_with_stop_share = get_third_parties_with_stop_share(collection)
print(third_parties_with_stop_share)
# print(len(third_parties_with_stop_share))
# Out:
# ['google firebase', 'facebook', 'cleverTap', 'appLovin', 'kochava', 'braze', 'sentry', 'appsflyer', 'vungle', 'baidu', 'urban airship', 'branch', 'ironsource', 'ogury', 'moengage', 'Instabug', 'pushwoosh', 'bugsnag', 'onesignal', 'smaato', 'repro', 'batch', 'Taboola', 'Smart AdServer', 'Adjust', 'Samsung Health', 'Kakao', 'Heap Analytics', 'Digital Turbine', 'PubNative', 'Unity Ads', 'Braintree', 'Iterable', 'New Relic', 'Mixpanel', 'MobileFuse', 'chartbeat', 'swrve', 'Adobe', 'Naver', 'Adyen', 'HyprMX (Amazon)', 'Blueshift', 'optimizely', 'Chartboost', 'MParticle', 'UXCam', 'LogRocket', 'ACRA', 'Smartlook', 'Singular', 'Contentsquare', 'Localytics', 'CustomerIO', 'Sailthru']

# %%
for i in range(15, len(third_parties_with_stop_share)):
    print("---------------- Loop-"+str(i)+" ----------------")
    third_party_name = third_parties_with_stop_share[i]
    print("Third party name: ",third_party_name)
    directory_path = os.path.join(root_directory, third_party_name)
    print("Directory path: ",directory_path)
    file_arr = get_files_with_extension(directory_path, ".java","wrap-")
    print("file_arr: ",file_arr)
    for j in range(len(file_arr)):
        code_file_path = file_arr[j]
        print("Code file path: ",code_file_path)
        # Read JAVA from file
        java_code = read_java_code_from_file(code_file_path)
        sanitize_java_code = sanitize_code(java_code)
        # Create AST
        if java_code:
            ast_paths = extract_ast_paths(sanitize_java_code)
            save_ast_path = directory_path+"//"+"ast-"+str(j)+".txt"
            # Write to file
            with open(save_ast_path, "w", encoding='utf-8') as f:
                for path in ast_paths:
                    f.write(path + "\n")
                    
            print("AST paths have been saved")
    # break
# Out:
# ---------------- Loop-6 ----------------
# Third party name:  sentry
# Directory path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\sentry
# file_arr:  ['C:\\Users\\ASUS\\anaconda3-project-code\\wearable-2-rag\\rag-external-data\\sentry\\wrap-java-0.java', 'C:\\Users\\ASUS\\anaconda3-project-code\\wearable-2-rag\\rag-external-data\\sentry\\wrap-java-1.java']
# Code file path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\sentry\wrap-java-0.java
# Error parsing Java code:
# AST paths have been saved
# Code file path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\sentry\wrap-java-1.java
# Error parsing Java code:
# AST paths have been saved
# ---------------- Loop-7 ----------------
# Third party name:  appsflyer
# Directory path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\appsflyer
# file_arr:  ['C:\\Users\\ASUS\\anaconda3-project-code\\wearable-2-rag\\rag-external-data\\appsflyer\\wrap-java-0.java', 'C:\\Users\\ASUS\\anaconda3-project-code\\wearable-2-rag\\rag-external-data\\appsflyer\\wrap-java-1.java']
# Code file path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\appsflyer\wrap-java-0.java
# AST paths have been saved
# Code file path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\appsflyer\wrap-java-1.java
# Error parsing Java code:
# AST paths have been saved
# ---------------- Loop-8 ----------------
# Third party name:  vungle
# Directory path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\vungle
# file_arr:  ['C:\\Users\\ASUS\\anaconda3-project-code\\wearable-2-rag\\rag-external-data\\vungle\\wrap-java-0.java', 'C:\\Users\\ASUS\\anaconda3-project-code\\wearable-2-rag\\rag-external-data\\vungle\\wrap-java-1.java']
# Code file path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\vungle\wrap-java-0.java
# AST paths have been saved
# Code file path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\vungle\wrap-java-1.java
# Error parsing Java code:
# AST paths have been saved
# ---------------- Loop-9 ----------------
# Third party name:  baidu
# Directory path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\baidu
# file_arr:  ['C:\\Users\\ASUS\\anaconda3-project-code\\wearable-2-rag\\rag-external-data\\baidu\\wrap-java-0.java']
# Code file path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\baidu\wrap-java-0.java
# Error parsing Java code:
# AST paths have been saved
# ---------------- Loop-10 ----------------
# Third party name:  urban airship
# Directory path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\urban airship
# file_arr:  ['C:\\Users\\ASUS\\anaconda3-project-code\\wearable-2-rag\\rag-external-data\\urban airship\\wrap-java-0.java', 'C:\\Users\\ASUS\\anaconda3-project-code\\wearable-2-rag\\rag-external-data\\urban airship\\wrap-java-1.java']
# Code file path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\urban airship\wrap-java-0.java
# AST paths have been saved
# Code file path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\urban airship\wrap-java-1.java
# AST paths have been saved
# ---------------- Loop-11 ----------------
# Third party name:  branch
# Directory path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\branch
# file_arr:  ['C:\\Users\\ASUS\\anaconda3-project-code\\wearable-2-rag\\rag-external-data\\branch\\wrap-java-0.java']
# Code file path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\branch\wrap-java-0.java
# AST paths have been saved
# ---------------- Loop-12 ----------------
# Third party name:  ironsource
# Directory path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\ironsource
# file_arr:  ['C:\\Users\\ASUS\\anaconda3-project-code\\wearable-2-rag\\rag-external-data\\ironsource\\wrap-java-0.java']
# Code file path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\ironsource\wrap-java-0.java
# AST paths have been saved
# ---------------- Loop-13 ----------------
# Third party name:  ogury
# Directory path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\ogury
# file_arr:  ['C:\\Users\\ASUS\\anaconda3-project-code\\wearable-2-rag\\rag-external-data\\ogury\\wrap-java-0.java']
# Code file path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\ogury\wrap-java-0.java
# Error parsing Java code:
# AST paths have been saved
# ---------------- Loop-14 ----------------
# Third party name:  moengage
# Directory path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\moengage
# file_arr:  ['C:\\Users\\ASUS\\anaconda3-project-code\\wearable-2-rag\\rag-external-data\\moengage\\wrap-java-0.java']
# Code file path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\moengage\wrap-java-0.java
# AST paths have been saved
# ---------------- Loop-15 ----------------
# Third party name:  Instabug
# Directory path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\Instabug
# file_arr:  ['C:\\Users\\ASUS\\anaconda3-project-code\\wearable-2-rag\\rag-external-data\\Instabug\\wrap-java-0.java']
# Code file path:  C:\Users\ASUS\anaconda3-project-code\wearable-2-rag\rag-external-data\Instabug\wrap-java-0.java
# ---------------------------------------------------------------------------
# LexerError                                Traceback (most recent call last)
# Cell In[25], line 17
#      15 # Create AST
#      16 if java_code:
# ---> 17     ast_paths = extract_ast_paths(sanitize_java_code)
#      18     save_ast_path = directory_path+"//"+"ast-"+str(j)+".txt"
#      19     # Write to file
#
# Cell In[22], line 37, in extract_ast_paths(code)
#      35 def extract_ast_paths(code: str) -> List[str]:
#      36     try:
# ---> 37         tree = javalang.parse.parse(code)
#      38     except javalang.parser.JavaSyntaxError as e:
#      39         print(f"Error parsing Java code: {e}")
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\javalang\parse.py:52, in parse(s)
#      50 def parse(s):
#      51     tokens = tokenize(s)
# ---> 52     parser = Parser(tokens)
#      53     return parser.parse()
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\javalang\parser.py:95, in Parser.__init__(self, tokens)
#      94 def __init__(self, tokens):
# ---> 95     self.tokens = util.LookAheadListIterator(tokens)
#      96     self.tokens.set_default(EndOfInput(None))
#      98     self.debug = False
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\javalang\util.py:92, in LookAheadListIterator.__init__(self, iterable)
#      91 def __init__(self, iterable):
# ---> 92     self.list = list(iterable)
#      94     self.marker = 0
#      95     self.saved_markers = []
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\javalang\tokenizer.py:547, in JavaTokenizer.tokenize(self)
#     544     token_type = Operator
#     546 else:
# --> 547     self.error('Could not process token', c)
#     548     self.i = self.i + 1
#     549     continue
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\javalang\tokenizer.py:576, in JavaTokenizer.error(self, message, char)
#     573 self.errors.append(error)
#     575 if not self.ignore_errors:
# --> 576     raise error
#
# LexerError: Could not process token at "\", line 13: curl -XDELETE 'https://api.instabug.com/api/web/public/users/v1'\?application_token\="app_token"\&email\="email"
