# %%
from pymongo import MongoClient
import os

# %%
def connect_mongodb(uri, db_name, collection_name):
    # Connect to MongoDB 
    client = MongoClient(uri)
    
    # Select the database and collection
    db = client[db_name]
    collection = db[collection_name]
    
    return collection
def get_third_parties_with_stop_share(collection):
    # Query to find all documents where "stop_share" is "yes"
    results = collection.find({"stop_share": "yes"}, {"third_party": 1, "_id": 0})
    third_parties = [item["third_party"] for item in results]
    return third_parties
def create_directory_if_not_exist(dir_path):
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
        print(f"Directory created: {dir_path}")
    else:
        print(f"Directory already exists: {dir_path}")

# %%
# server
mongoDB_uri = 'mongodb://localhost:27017'
mongoDB_database = 'wearable-project-2' 
mongoDB_collection = 'third_party_services'
# directory
root_directory = r"C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data"

# %%
# Connect to the MongoDB collection
collection = connect_mongodb(mongoDB_uri,mongoDB_database,mongoDB_collection)
third_parties_with_stop_share = get_third_parties_with_stop_share(collection)
# print(third_parties_with_stop_share)
print(len(third_parties_with_stop_share))
# Out:
# 55

# %%
for i in range(len(third_parties_with_stop_share)):
    print("-------------Loop-"+str(i)+"-------------")
    third_party_name = third_parties_with_stop_share[i]
    print("Third party name: ",third_party_name)
    third_party_directory = os.path.join(root_directory, third_party_name)
    print("Third party directory:", third_party_directory)
    create_directory_if_not_exist(third_party_directory)
# Out:
# -------------Loop-0-------------
# Third party name:  google firebase
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\google firebase
# -------------Loop-1-------------
# Third party name:  facebook
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\facebook
# -------------Loop-2-------------
# Third party name:  cleverTap
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\cleverTap
# -------------Loop-3-------------
# Third party name:  appLovin
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\appLovin
# -------------Loop-4-------------
# Third party name:  kochava
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\kochava
# -------------Loop-5-------------
# Third party name:  braze
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\braze
# -------------Loop-6-------------
# Third party name:  sentry
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\sentry
# -------------Loop-7-------------
# Third party name:  appsflyer
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\appsflyer
# -------------Loop-8-------------
# Third party name:  vungle
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\vungle
# -------------Loop-9-------------
# Third party name:  baidu
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\baidu
# -------------Loop-10-------------
# Third party name:  urban airship
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\urban airship
# -------------Loop-11-------------
# Third party name:  branch
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\branch
# -------------Loop-12-------------
# Third party name:  ironsource
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\ironsource
# -------------Loop-13-------------
# Third party name:  ogury
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\ogury
# -------------Loop-14-------------
# Third party name:  moengage
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\moengage
# -------------Loop-15-------------
# Third party name:  Instabug
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Instabug
# -------------Loop-16-------------
# Third party name:  pushwoosh
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\pushwoosh
# -------------Loop-17-------------
# Third party name:  bugsnag
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\bugsnag
# -------------Loop-18-------------
# Third party name:  onesignal
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\onesignal
# -------------Loop-19-------------
# Third party name:  smaato
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\smaato
# -------------Loop-20-------------
# Third party name:  repro
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\repro
# -------------Loop-21-------------
# Third party name:  batch
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\batch
# -------------Loop-22-------------
# Third party name:  Taboola
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Taboola
# -------------Loop-23-------------
# Third party name:  Smart AdServer
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Smart AdServer
# -------------Loop-24-------------
# Third party name:  Adjust
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Adjust
# -------------Loop-25-------------
# Third party name:  Samsung Health
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Samsung Health
# -------------Loop-26-------------
# Third party name:  Kakao
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Kakao
# -------------Loop-27-------------
# Third party name:  Heap Analytics
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Heap Analytics
# -------------Loop-28-------------
# Third party name:  Digital Turbine
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Digital Turbine
# -------------Loop-29-------------
# Third party name:  PubNative
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\PubNative
# -------------Loop-30-------------
# Third party name:  Unity Ads
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Unity Ads
# -------------Loop-31-------------
# Third party name:  Braintree
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Braintree
# -------------Loop-32-------------
# Third party name:  Iterable
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Iterable
# -------------Loop-33-------------
# Third party name:  New Relic
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\New Relic
# -------------Loop-34-------------
# Third party name:  Mixpanel
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Mixpanel
# -------------Loop-35-------------
# Third party name:  MobileFuse
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\MobileFuse
# -------------Loop-36-------------
# Third party name:  chartbeat
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\chartbeat
# -------------Loop-37-------------
# Third party name:  swrve
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\swrve
# -------------Loop-38-------------
# Third party name:  Adobe
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Adobe
# -------------Loop-39-------------
# Third party name:  Naver
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Naver
# -------------Loop-40-------------
# Third party name:  Adyen
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Adyen
# -------------Loop-41-------------
# Third party name:  HyprMX (Amazon)
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\HyprMX (Amazon)
# -------------Loop-42-------------
# Third party name:  Blueshift
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Blueshift
# -------------Loop-43-------------
# Third party name:  optimizely
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\optimizely
# -------------Loop-44-------------
# Third party name:  Chartboost
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Chartboost
# -------------Loop-45-------------
# Third party name:  MParticle
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\MParticle
# -------------Loop-46-------------
# Third party name:  UXCam
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\UXCam
# -------------Loop-47-------------
# Third party name:  LogRocket
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\LogRocket
# -------------Loop-48-------------
# Third party name:  ACRA
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\ACRA
# -------------Loop-49-------------
# Third party name:  Smartlook
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Smartlook
# -------------Loop-50-------------
# Third party name:  Singular
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Singular
# -------------Loop-51-------------
# Third party name:  Contentsquare
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Contentsquare
# -------------Loop-52-------------
# Third party name:  Localytics
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Localytics
# -------------Loop-53-------------
# Third party name:  CustomerIO
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\CustomerIO
# -------------Loop-54-------------
# Third party name:  Sailthru
# Third party directory: C:\Users\ASUS\anaconda3-project-code\wearable-2-rag-external-data\rag-external-data\Sailthru
