# %%
from pymongo import MongoClient
import re
import os
from typing import Dict, Any, Union, List
from pymongo import MongoClient
import json
from dotenv import load_dotenv
# Langchain load data
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders import DirectoryLoader
### LLMs - Langchain
import openai
from langchain_core.prompts import ChatPromptTemplate
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain.chat_models import init_chat_model
### Summary chain
from langchain.prompts import PromptTemplate, ChatPromptTemplate
from langchain.chains import LLMChain, MapReduceChain, load_summarize_chain
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
from langchain_community.document_loaders import TextLoader

# %%
def connect_mongodb(uri,db_name, collection_name):
    # Connect to MongoDB 
    client = MongoClient(uri)
    
    # Select the database and collection
    db = client[db_name]
    collection = db[collection_name]
    
    return collection
def extract_compliance_info(document: Dict[str, Any]) -> Union[Dict[str, Any], None]:
    """
    Extract _id, 3rd_integration, and privacy-compliance.violate if privacy-compliance.privacy-compliance is 'no'.

    Args:
        document (Dict[str, Any]): A single document from the MongoDB collection.

    Returns:
        Dict[str, Any] or None: A dictionary containing the extracted information if conditions are met, otherwise None.
    """
    if document.get("privacy-compliance", {}).get("privacy-compliance") == "no":
        return {
            "_id": document.get("_id"),
            "3rd_integration": document.get("3rd_integration"),
            "privacy-compliance.violate": document.get("privacy-compliance", {}).get("violate")
        }
    return None


def fetch_compliance_violations(collection) -> List[Dict[str, Any]]:
    """
    Fetch all documents from the collection and filter those with privacy compliance violations.
    
    Args:
        collection (pymongo.collection.Collection): The MongoDB collection to query.

    Returns:
        List[Dict[str, Any]]: A list of filtered documents with compliance violations.
    """
    results = []
    for document in collection.find():
        filtered_info = extract_compliance_info(document)
        if filtered_info:
            results.append(filtered_info)
    return results


def create_prompt_with_third_party_integration(third_party_integration: dict) -> str:
    """
    Generate a LangChain prompt for extracting import statements from third-party integrations.

    Args:
        third_party_integration (dict): A dictionary containing third-party integration details.

    Returns:
        str: A formatted prompt ready to be sent to a LangChain model.
    """
    # Convert the dictionary to a pretty-printed JSON string for the prompt
    third_party_integration_str = json.dumps(third_party_integration, indent=4)
    
    prompt_template = PromptTemplate(
        input_variables=["third_party_integration"],
        template="""
        Given that the app connects with the following third-party services:
        {third_party_integration}
        
        Provide me with the keywords or import statements that the app would use to connect with each third-party service above.

        Format the response as a JSON object where each third-party name is a key and the corresponding list of import statements is the value.

        Example format:
        {{
            "Google": ["import com.google.firebase.messaging.FirebaseMessagingService", "import com.google.firebase.messaging.RemoteMessage"],
            "Facebook": ["import com.facebook.FacebookSdk", "import com.facebook.appevents.AppEventsLogger"]
        }}
        If you can't find keywords or import statements then return as follows
        {{
            "keyword": []
        }}
        Provide the complete list of imports for each of the specified services.
        Please return the JSON object only and don't add any explanation or additional information.
        """
    )
    
    return prompt_template.format(third_party_integration=third_party_integration_str)
def extract_output_text_as_dict(response):
    """
    Extracts the 'output_text' from the response, cleans it, and converts it into a dictionary.

    :param response: The response dictionary containing 'output_text'.
    :return: A dictionary parsed from the 'output_text', or an empty dict if parsing fails.
    """
    if not response or not hasattr(response, "content"):  # Ensure response is valid
        print("Error: Invalid response object.")
        return {}

    output_text = response.content  # Assuming response.content holds the JSON string

    # Remove code block markers (```json and ```) if present
    if output_text.startswith("```json"):
        output_text = output_text[len("```json"):].strip("`").strip()

    try:
        # Convert the cleaned JSON string into a dictionary
        output_dict = json.loads(output_text)
        return output_dict
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        return {}  # Return an empty dictionary instead of None
def insert_third_party_data(collection, condition_value: str, data: Dict[str, list]):
    """
    Insert or update the given dictionary data into MongoDB under the field 'keyword' using _id as condition.

    Args:
        collection (pymongo.collection.Collection): The MongoDB collection to interact with.
        condition_value (str): The _id value to use as a condition for insertion.
        data (Dict[str, list]): The dictionary data to insert or update.

    Returns:
        pymongo.results.UpdateResult: The result of the MongoDB update operation.
    """
    filter_query = {"_id": condition_value}
    update_query = {"$set": {"third-party-keyword": data}}
    
    # Insert or update the document using upsert=True
    result = collection.update_one(filter_query, update_query, upsert=True)
    return result
def extract_keywords(data: Dict[str, List[str]]) -> List[str]:
    """
    Extract keywords from the given dictionary and return them as a list.

    Args:
        data (Dict[str, List[str]]): The dictionary containing keywords as keys.

    Returns:
        List[str]: A list of keywords from the dictionary.
    """
    return list(data.keys())

# %%
# server
mongoDB_uri = 'mongodb://localhost:27017'
mongoDB_database = 'wearable-project' 
mongoDB_collection = 'wearable-standalone-02-04-2025'
# local
# mongoDB_uri = 'mongodb://localhost:27017'
# mongoDB_database = 'wearable-project' 
# mongoDB_collection = 'wearable-standalone-31-03-2025'
# root_directory = r'E:\wearable-standalone-code-extraction'
source_code_root_directory = r"E:\wearable-project-decompile-source\source-code-standalone"

# %%
#. Chat model
# Setup model
# Load environment variables
load_dotenv()

# Retrieve API key
api_key = os.getenv("OPENAI_API_KEY")
# Ensure the API key is correctly set
if not api_key:
    raise ValueError("OPENAI_API_KEY is not set in the environment variables")

# Initialize the ChatOpenAI model
llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0,
    openai_api_key=api_key  # Ensure you explicitly pass the API key
)

# %%
# Connect to the MongoDB collection
collection = connect_mongodb(mongoDB_uri,mongoDB_database,mongoDB_collection)
# Fetch compliance violations
violations = fetch_compliance_violations(collection)

# Display results
for i in range(len(violations)):
    print("------------------ Loop-"+str(i)+" ------------------")
    data = violations[i]
    app_id = data["_id"]
    app_3rd_integration = data["3rd_integration"]
    app_3rd_keyword = extract_keywords(app_3rd_integration)
    # print(type(app_3rd_integration))
    print("App id: ", app_id)
    print("App 3rd party: ",app_3rd_integration)
    print("App 3rd party keyword: ",app_3rd_keyword)
# Out:
# ------------------ Loop-0 ------------------
# App id:  in.codeseed.audify
# App 3rd party:  {'Google': 'com.google.firebase.auth.api.gms.service.START, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.cast.framework.media.MediaIntentReceiver, com.google.android.gms.analytics.globalConfigResource, com.android.vending.BILLING, com.google.android.play.billingclient.version, io.fabric.ApiKey'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-1 ------------------
# App id:  com.urbandroid.lux
# App 3rd party:  {'Google': 'com.google.android.gms.version, com.google.android.gms.wearable.MESSAGE_RECEIVED'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-2 ------------------
# App id:  maxcom.toolbox.altimeter
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.version, com.google.android.gms.ads.APPLICATION_ID'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-3 ------------------
# App id:  com.mauriciotogneri.shoppinglist
# App 3rd party:  {'Google': 'com.google.android.gms.analytics.AnalyticsReceiver, com.google.android.gms.analytics.AnalyticsService, com.google.android.gms.analytics.AnalyticsJobService', 'Crashlytics': 'com.crashlytics.android.CrashlyticsInitProvider'}
# App 3rd party keyword:  ['Google', 'Crashlytics']
# ------------------ Loop-4 ------------------
# App id:  com.szyk.myheart
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, com.android.vending.BILLING, com.android.vending.billing.InAppBillingService.BIND, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.measurement.AppMeasurementService, com.google.mlkit.common.internal.MlKitComponentDiscoveryService, com.google.android.gms.auth.api.signin.RevocationBoundService'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-5 ------------------
# App id:  je.fit
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.analytics.ANALYTICS_DISPATCH, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.ads.AdService', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.sdk.ACTION_CURRENT_AUTHENTICATION_TOKEN_CHANGED, com.facebook.FacebookContentProvider, com.facebook.internal.FacebookInitProvider'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-6 ------------------
# App id:  com.appfour.wearvideos
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.android.vending.BILLING, com.google.android.gms.analytics.AnalyticsReceiver, AnalyticsService, AnalyticsJobService, com.google.android.gms.auth.api.signin.RevocationBoundService'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-7 ------------------
# App id:  com.naing.englishmyanmardictionary
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.version, com.google.android.gms.ads.APPLICATION_ID', 'Facebook': 'com.facebook.ads.internal.ipc.AdsProcessPriorityService, com.facebook.ads.internal.ipc.AdsMessengerService'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-8 ------------------
# App id:  de.svz
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.android.gms.ads.MobileAdsInitProvider, com.google.firebase.provider.FirebaseInitProvider', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED', 'Advertising': 'android.permission.ACCESS_ADSERVICES_AD_ID'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising']
# ------------------ Loop-9 ------------------
# App id:  com.komparato.informer.wear
# App 3rd party:  {'Google': 'com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.measurement.AppMeasurementReceiver, com.google.android.play.core.assetpacks, com.android.vending.BILLING'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-10 ------------------
# App id:  com.glidetalk.glideapp
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.android.gms.measurement.AppMeasurementService, com.google.android.gms.permission.AD_ID', 'Facebook': 'com.facebook.ads.AudienceNetworkContentProvider'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-11 ------------------
# App id:  uk.me.andre.dicionarioportugues
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.android.vending.INSTALL_REFERRER, com.crashlytics.android.CrashlyticsInitProvider'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-12 ------------------
# App id:  com.link.messages.sms
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.iid.FirebaseInstanceIdReceiver, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.measurement.AppMeasurementReceiver, com.google.android.gms.measurement.AppMeasurementService', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.sdk.ACTION_CURRENT_AUTHENTICATION_TOKEN_CHANGED', 'AppLovin': 'com.applovin.sdk.AppLovinInitProvider', 'Vungle': 'com.vungle.warren.utility.VungleProvider'}
# App 3rd party keyword:  ['Google', 'Facebook', 'AppLovin', 'Vungle']
# ------------------ Loop-13 ------------------
# App id:  com.kiss.keeper
# App 3rd party:  {'Google': 'com.google.android.gms.version'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-14 ------------------
# App id:  com.rokontrol.android
# App 3rd party:  {'Google': 'com.google.android.gms.wearable.BIND_LISTENER, com.google.android.gms.version, com.google.android.wearable.beta.app'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-15 ------------------
# App id:  com.skimble.workouts
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.measurement.AppMeasurementService, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.android.gms.fitness.sdk.version', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.sdk.ACTION_CURRENT_AUTHENTICATION_TOKEN_CHANGED, com.facebook.internal.FacebookInitProvider', 'Advertising': 'com.google.android.gms.ads.APPLICATION_ID, com.google.android.gms.permission.AD_ID'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising']
# ------------------ Loop-16 ------------------
# App id:  pl.tweeba.mobile.learning.english
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.permission.AD_ID', 'Facebook': 'com.facebook.internal.FacebookInitProvider'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-17 ------------------
# App id:  org.obduro.kentekeninfo
# App 3rd party:  {'Firebase': 'com.google.firebase.provider.FirebaseInitProvider', 'Google Play Services': 'com.google.android.finsky.permission.BIND_GET_INSTALL_REFERRER_SERVICE, com.google.android.gms.version', 'Google Analytics': 'com.google.android.gms.measurement.AppMeasurementService', 'Advertising': 'com.google.android.gms.permission.AD_ID, android.permission.ACCESS_ADSERVICES_ATTRIBUTION, android.permission.ACCESS_ADSERVICES_AD_ID'}
# App 3rd party keyword:  ['Firebase', 'Google Play Services', 'Google Analytics', 'Advertising']
# ------------------ Loop-18 ------------------
# App id:  ru.starline
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.analytics.AnalyticsService, com.google.android.maps.v2.API_KEY, com.android.vending.INSTALL_REFERRER, com.google.firebase.provider.FirebaseInitProvider'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-19 ------------------
# App id:  jp.co.yahoo.android.vassist
# App 3rd party:  {'Google Services': 'com.google.android.gms.permission.AD_ID, com.google.firebase.provider.FirebaseInitProvider, com.google.firebase.components.ComponentDiscoveryService, com.google.android.gms.analytics.AnalyticsService, com.google.android.gms.analytics.AnalyticsJobService', 'Advertising': 'com.google.android.gms.ads.AD_MANAGER_APP'}
# App 3rd party keyword:  ['Google Services', 'Advertising']
# ------------------ Loop-20 ------------------
# App id:  com.spotify.music
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.android.gms.permission.AD_ID, com.google.firebase.messaging.FirebaseMessagingService', 'Facebook Services': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED', 'Advertising': 'android.permission.ACCESS_ADSERVICES_ATTRIBUTION, android.permission.ACCESS_ADSERVICES_AD_ID'}
# App 3rd party keyword:  ['Google Services', 'Facebook Services', 'Advertising']
# ------------------ Loop-21 ------------------
# App id:  oms.mmc.fortunetelling.gmpay.almanac2
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.ads.MobileAdsInitProvider', 'Facebook': 'com.facebook.ads.AudienceNetworkContentProvider', 'Advertising': 'com.applovin.sdk.AppLovinInitProvider', 'Baidu': 'com.baidu.location.f'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising', 'Baidu']
# ------------------ Loop-22 ------------------
# App id:  com.mictale.gpsessentials
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.analytics.AnalyticsReceiver, com.google.android.gms.measurement.AppMeasurementReceiver, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.ads.AD_MANAGER_APP'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-23 ------------------
# App id:  com.ktmusic.geniemusic
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.permission.AD_ID, com.google.firebase.provider.FirebaseInitProvider', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.sdk.ACTION_CURRENT_AUTHENTICATION_TOKEN_CHANGED, com.facebook.sdk.ApplicationId, com.facebook.sdk.ClientToken'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-24 ------------------
# App id:  net.familo.android
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.permission.AD_ID', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.sdk.ACTION_CURRENT_AUTHENTICATION_TOKEN_CHANGED', 'Advertising': 'com.android.vending.BILLING'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising']
# ------------------ Loop-25 ------------------
# App id:  com.cpsolutions.contacts
# App 3rd party:  {'Google': 'com.google.android.gms.wearable.MESSAGE_RECEIVED, com.google.android.gms.analytics.CampaignTrackingReceiver, com.google.android.gms.analytics.AnalyticsReceiver, com.google.android.gms.analytics.CampaignTrackingService, com.google.android.gms.analytics.AnalyticsService, com.google.android.gms.analytics.AnalyticsJobService'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-26 ------------------
# App id:  com.directed.android.viper
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.android.gms.analytics.AnalyticsReceiver, AnalyticsService, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.measurement.AppMeasurementService', 'Urban Airship': 'com.urbanairship.push.OPENED', 'Amazon Device Messaging': 'com.amazon.device.messaging.permission.RECEIVE'}
# App 3rd party keyword:  ['Google Services', 'Urban Airship', 'Amazon Device Messaging']
# ------------------ Loop-27 ------------------
# App id:  com.lucky_ponies.dokin
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.android.gms.measurement, com.google.android.maps.v2.API_KEY'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-28 ------------------
# App id:  com.toshremote.view
# App 3rd party:  {'Google': 'com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.ads.APPLICATION_ID, com.google.firebase.provider.FirebaseInitProvider, firebase_crashlytics_collection_enabled, com.google.firebase.components:com.google.firebase.analytics.ktx.FirebaseAnalyticsKtxRegistrar, com.google.android.gms.permission.AD_ID, com.google.android.gms.version'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-29 ------------------
# App id:  nl.birdssoftware.mondaymorning
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.android.gms.measurement.AppMeasurementContentProvider, AppMeasurementReceiver, AppMeasurementService, com.google.android.gms.auth.api.signin.RevocationBoundService'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-30 ------------------
# App id:  com.dusiassistant
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.android.gms.wearable.BIND_LISTENER'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-31 ------------------
# App id:  revox.voxnet
# App 3rd party:  {}
# App 3rd party keyword:  []
# ------------------ Loop-32 ------------------
# App id:  com.nstudio.weatherhere.free
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.permission.AD_ID, com.google.android.gms.measurement.AppMeasurementReceiver, com.google.android.gms.wearable.DATA_CHANGED', 'Facebook': 'com.facebook.ads.AudienceNetworkContentProvider', 'AppLovin': 'com.applovin.sdk.AppLovinInitProvider, com.applovin.impl.adview.activity.FullscreenAdService'}
# App 3rd party keyword:  ['Google', 'Facebook', 'AppLovin']
# ------------------ Loop-33 ------------------
# App id:  com.pocketlifestyle.music.tune
# App 3rd party:  {'Facebook SDK': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.internal.FacebookInitProvider, com.facebook.CurrentAccessTokenExpirationBroadcastReceiver', 'Google Mobile Ads': 'com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.ads.AD_MANAGER_APP', 'Branch SDK': 'io.branch.sdk.TestMode, io.branch.sdk.BranchKey, io.branch.sdk.BranchKey.test'}
# App 3rd party keyword:  ['Facebook SDK', 'Google Mobile Ads', 'Branch SDK']
# ------------------ Loop-34 ------------------
# App id:  com.dolcegustofree.activity
# App 3rd party:  {'Google Services': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.ads.APPLICATION_ID, com.google.android.gms.wearable.MESSAGE_RECEIVED', 'Advertising Services': 'android.permission.ACCESS_ADSERVICES_AD_ID, android.permission.ACCESS_ADSERVICES_ATTRIBUTION, android.permission.ACCESS_ADSERVICES_TOPICS', 'Wear OS Communication': 'com.dolcegusto.service.MyWearableListenerService'}
# App 3rd party keyword:  ['Google Services', 'Advertising Services', 'Wear OS Communication']
# ------------------ Loop-35 ------------------
# App id:  com.palaspro.listainteligentecompra
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.INSTANCE_ID_EVENT, com.google.android.gms.analytics.AnalyticsReceiver, com.google.android.gms.analytics.AnalyticsService, com.google.firebase.messaging.FirebaseMessagingService, com.google.firebase.iid.FirebaseInstanceIdService, com.google.android.gms.wearable.DATA_CHANGED, com.google.android.gms.wearable.MESSAGE_RECEIVED', 'Crashlytics': 'com.crashlytics.android.CrashlyticsInitProvider'}
# App 3rd party keyword:  ['Google Services', 'Crashlytics']
# ------------------ Loop-36 ------------------
# App id:  com.estela
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.version, com.google.firebase.perf.provider.FirebasePerfProvider, com.google.firebase.components:com.google.firebase.analytics.connector.internal.AnalyticsConnectorRegistrar, com.google.firebase.components:com.google.firebase.crashlytics.CrashlyticsRegistrar, com.google.android.gms.wearable.DATA_CHANGED, com.google.android.gms.wearable.MESSAGE_RECEIVED, com.google.android.gms.wearable.CAPABILITY_CHANGED'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-37 ------------------
# App id:  com.k560.luciddreaminducer
# App 3rd party:  {'Google': 'com.google.android.play.core.assetpacks'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-38 ------------------
# App id:  com.aircanada
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.ads.APPLICATION_ID, com.google.mlkit.vision.DEPENDENCIES, com.google.mlkit.common.internal.MlKitComponentDiscoveryService, com.google.firebase.components:com.google.firebase.analytics.connector.internal.AnalyticsConnectorRegistrar'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-39 ------------------
# App id:  fi.hhtec.coach4pro
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.provider.FirebaseInitProvider, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.version'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-40 ------------------
# App id:  com.cisco.webex.meetings
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.wearable.BIND_LISTENER, com.google.firebase.appindexing.UPDATE_INDEX, com.google.android.gms.auth.api.signin.RevocationBoundService', 'Microsoft Services': 'https://login.microsoftonline.com/common, com.microsoft.identity.client.ClientId'}
# App 3rd party keyword:  ['Google Services', 'Microsoft Services']
# ------------------ Loop-41 ------------------
# App id:  nl.dominos.android
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.analytics.AnalyticsReceiver, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.android.gms.permission.AD_ID, android.permission.ACCESS_ADSERVICES_AD_ID', 'Facebook': 'com.facebook.sdk.ApplicationId'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-42 ------------------
# App id:  nz.co.telecom.smartphone.android
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.ads.APPLICATION_ID, com.google.android.gms.permission.AD_ID, com.google.android.gms.ads.AD_MANAGER_APP', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.sdk.ApplicationId'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-43 ------------------
# App id:  com.acmeaom.android.myradar
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.c2dm.permission.RECEIVE, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.measurement.AppMeasurementService, com.google.android.gms.ads.APPLICATION_ID, com.google.android.gms.ads.AD_MANAGER_APP', 'Facebook': 'com.facebook.ads.AudienceNetworkContentProvider, com.facebook.sdk.ApplicationId'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-44 ------------------
# App id:  com.rageconsulting.android.lightflowlegacy
# App 3rd party:  {'Google Services': 'com.google.android.gms.permission.ACTIVITY_RECOGNITION, com.google.android.c2dm.permission.RECEIVE, com.google.firebase.INSTANCE_ID_EVENT, com.google.android.gms.gcm.ACTION_TASK_READY, com.google.android.gms.auth.api.signin.RevocationBoundService', 'Sony Services': 'com.sonyericsson.extras.liveware.aef.EXTENSION_PERMISSION', 'Pebble Services': 'com.getpebble.action.PEBBLE_CONNECTED, com.getpebble.action.PEBBLE_DISCONNECTED'}
# App 3rd party keyword:  ['Google Services', 'Sony Services', 'Pebble Services']
# ------------------ Loop-45 ------------------
# App id:  tr.com.fitwell.app
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.auth.api.signin.RevocationBoundService', 'Facebook': 'com.facebook.FacebookContentProvider, com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED', 'Advertising': 'com.google.android.gms.ads.AdService, com.facebook.ads.internal.ipc.AdsProcessPriorityService', 'Branch.io': 'io.branch.sdk.BranchKey'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising', 'Branch.io']
# ------------------ Loop-46 ------------------
# App id:  com.sasyabook.businesscardapp
# App 3rd party:  {'Google': 'com.android.vending.BILLING, com.android.vending.billing.InAppBillingService.BIND, com.google.android.gms.version, com.google.android.play.billingclient.version, com.google.android.wearable.beta.app'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-47 ------------------
# App id:  com.edjing.edjingdjturntable
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.ads.MobileAdsInitProvider', 'Facebook': 'com.facebook.FacebookContentProvider', 'Advertising': 'com.applovin.sdk.AppLovinInitProvider, com.vungle.ads.internal.util.VungleProvider, com.ironsource.lifecycle.IronsourceLifecycleProvider', 'Other': 'com.appsflyer.MultipleInstallBroadcastReceiver'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising', 'Other']
# ------------------ Loop-48 ------------------
# App id:  dev.niamor.wearliveboxremote
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.analytics.AnalyticsReceiver, com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.ads.MobileAdsInitProvider', 'AppLovin': 'com.applovin.sdk.AppLovinInitProvider', 'Vungle': 'com.vungle.ads.internal.util.VungleProvider', 'Facebook': 'com.facebook.ads.AudienceNetworkContentProvider', 'IronSource': 'com.ironsource.lifecycle.IronsourceLifecycleProvider', 'Picasso': 'com.squareup.picasso.PicassoProvider', 'Ogury': 'com.ogury.core.internal.OguryLogEnablerReceiver'}
# App 3rd party keyword:  ['Google', 'AppLovin', 'Vungle', 'Facebook', 'IronSource', 'Picasso', 'Ogury']
# ------------------ Loop-49 ------------------
# App id:  adarshurs.android.vlcmobileremote
# App 3rd party:  {'Google': 'com.google.firebase.provider.FirebaseInitProvider, com.google.firebase.components:com.google.firebase.analytics.connector.internal.AnalyticsConnectorRegistrar, com.google.android.gms.ads.MobileAdsInitProvider, com.android.vending.billing.InAppBillingService.BIND'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-50 ------------------
# App id:  com.bhphoto
# App 3rd party:  {'Google': 'com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.measurement.AppMeasurementService, AppMeasurementJobService, com.google.androidbrowserhelper.trusted.DelegationService'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-51 ------------------
# App id:  com.unated
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.mlkit', 'Facebook': 'com.facebook.soloader.enabled', 'Advertising': 'android.permission.ACCESS_ADSERVICES_ATTRIBUTION, android.permission.ACCESS_ADSERVICES_AD_ID'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising']
# ------------------ Loop-52 ------------------
# App id:  com.bandlab.bandlab
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.analytics.AnalyticsService', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED', 'Advertising': 'android.permission.ACCESS_ADSERVICES_AD_ID'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising']
# ------------------ Loop-53 ------------------
# App id:  com.SnowReport.screens
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.android.gms.permission.AD_ID, android.permission.ACCESS_ADSERVICES_ATTRIBUTION, FirebaseInitProvider, FirebaseCrashlyticsInitProvider, FirebaseAppInitProvider', 'Facebook': 'com.facebook.soloader.enabled', 'Advertising': 'android.permission.ACCESS_ADSERVICES_AD_ID'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising']
# ------------------ Loop-54 ------------------
# App id:  com.ubivelox.uvophone
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.android.gms.measurement.AppMeasurementService', 'Firebase': 'FirebaseMessagingKtxRegistrar, FirebaseDynamicLinksKtxRegistrar, FirebaseCrashlyticsKtxRegistrar', 'Kakao': 'com.kakao.sdk.AppKey'}
# App 3rd party keyword:  ['Google Services', 'Firebase', 'Kakao']
# ------------------ Loop-55 ------------------
# App id:  com.lf.lfvtandroid
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.firebase.provider.FirebaseInitProvider, com.google.mlkit.common.internal.MlKitInitProvider', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.sdk.ACTION_CURRENT_AUTHENTICATION_TOKEN_CHANGED, com.facebook.internal.FacebookInitProvider'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-56 ------------------
# App id:  com.biostatusfit.www
# App 3rd party:  {'Google': 'com.google.android.gms.analytics.AnalyticsReceiver, com.google.android.gms.analytics.CampaignTrackingReceiver, com.google.android.gms.analytics.AnalyticsService, com.google.android.gms.analytics.CampaignTrackingService, com.google.android.gms.version'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-57 ------------------
# App id:  com.fitnesskeeper.runkeeper.pro
# App 3rd party:  {'Google Services': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.cloudmessaging.FINISHED_AFTER_HANDLED, com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.auth.api.signin.RevocationBoundService', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.internal.FacebookInitProvider', 'Advertising': 'android.permission.ACCESS_ADSERVICES_ATTRIBUTION, android.permission.ACCESS_ADSERVICES_AD_ID'}
# App 3rd party keyword:  ['Google Services', 'Facebook', 'Advertising']
# ------------------ Loop-58 ------------------
# App id:  steptracker.healthandfitness.walkingtracker.pedometer
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.measurement.AppMeasurementReceiver, com.google.android.gms.measurement.AppMeasurementService, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.android.gms.ads.AdService, com.google.android.gms.ads.APPLICATION_ID', 'Facebook': 'com.facebook.ads.AudienceNetworkContentProvider'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-59 ------------------
# App id:  com.czw.freefit
# App 3rd party:  {'Google': 'com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.ads.APPLICATION_ID, com.google.android.gms.permission.AD_ID', 'Advertising': 'com.google.android.gms.permission.AD_ID', 'Amap': 'com.amap.api.v2.apikey'}
# App 3rd party keyword:  ['Google', 'Advertising', 'Amap']
# ------------------ Loop-60 ------------------
# App id:  com.topstep.fitcloudpro
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.geo.API_KEY, com.google.gms.fitness.sdk.version', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.sdk.ApplicationId, com.facebook.sdk.ClientToken', 'Huawei': 'com.huawei.hms.client.appid, com.huawei.hms.client.service.name:scanplus', 'Advertising': 'com.google.android.gms.permission.AD_ID'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Huawei', 'Advertising']
# ------------------ Loop-61 ------------------
# App id:  com.popularapp.thirtydayfitnesschallenge
# App 3rd party:  {'Google': 'com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.ads.MobileAdsInitProvider, com.android.vending.BILLING, com.google.android.play.billingclient.version, com.google.android.gms.measurement.AppMeasurementReceiver, AppMeasurementService', 'Facebook': 'com.facebook.ads.AudienceNetworkContentProvider', 'Advertising Services': 'com.my.target.common.MyTargetContentProvider'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising Services']
# ------------------ Loop-62 ------------------
# App id:  com.fitness22.running
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.analytics.AnalyticsReceiver, com.google.android.gms.measurement.AppMeasurementService, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.ads.MobileAdsInitProvider', 'Facebook': 'com.facebook.FacebookContentProvider, com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED', 'Advertising': 'com.fyber.inneractive.sdk.intent.action.REGISTER_KIT', 'Crash Reporting': 'com.crashlytics.android.CrashlyticsInitProvider'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising', 'Crash Reporting']
# ------------------ Loop-63 ------------------
# App id:  women.workout.female.fitness
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.ads.MobileAdsInitProvider, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.measurement.AppMeasurementService', 'Facebook': 'com.facebook.ads.AudienceNetworkContentProvider'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-64 ------------------
# App id:  com.lafitness.lafitness
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.maps.v2.API_KEY, com.google.android.finsky.permission.BIND_GET_INSTALL_REFERRER_SERVICE, com.google.android.gms.measurement.AppMeasurementService, android.permission.ACCESS_ADSERVICES_ATTRIBUTION, android.permission.ACCESS_ADSERVICES_AD_ID'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-65 ------------------
# App id:  loseweight.weightloss.workout.fitness
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.measurement.AppMeasurementReceiver, com.google.android.gms.measurement.AppMeasurementService, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.auth.api.signin.RevocationBoundService', 'Facebook': 'com.facebook.ads.AudienceNetworkContentProvider', 'Advertising': 'com.my.target.common.MyTargetContentProvider'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising']
# ------------------ Loop-66 ------------------
# App id:  com.benda.fitpro
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.auth.api.signin.RevocationBoundService', 'Advertising and Analytics': 'android.adservices.AD_SERVICES_CONFIG, FirebaseAnalytics, FirebaseCrashlytics', 'Other Services': 'org.eclipse.paho.android.service.MqttService'}
# App 3rd party keyword:  ['Google Services', 'Advertising and Analytics', 'Other Services']
# ------------------ Loop-67 ------------------
# App id:  com.walkfit.weightloss.steptracker.pedometer
# App 3rd party:  {'Google Services': 'com.google.android.gms.permission.ACTIVITY_RECOGNITION, android.permission.ACTIVITY_RECOGNITION, com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.android.gms.measurement.AppMeasurementService, com.google.android.gms.permission.AD_ID, android.permission.ACCESS_ADSERVICES_AD_ID', 'Appsflyer': 'com.appsflyer.referrer.INSTALL_PROVIDER'}
# App 3rd party keyword:  ['Google Services', 'Appsflyer']
# ------------------ Loop-68 ------------------
# App id:  com.blinkfitness.app
# App 3rd party:  {'Google': 'com.google.android.gms.version'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-69 ------------------
# App id:  com.plaifit.plaifit
# App 3rd party:  {'Google Services': 'com.google.android.gms.permission.AD_ID, com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.components.ComponentRegistrar', 'Advertising': 'com.google.android.gms.ads.MobileAdsInitProvider', 'Amazon Services': 'com.amazon.device.iap.ResponseReceiver'}
# App 3rd party keyword:  ['Google Services', 'Advertising', 'Amazon Services']
# ------------------ Loop-70 ------------------
# App id:  dance.fit.zumba.weightloss.danceburn
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.android.vending.BILLING, com.google.firebase.components:com.google.firebase.crashlytics.FirebaseCrashlyticsKtxRegistrar', 'Advertising': 'com.google.android.gms.permission.AD_ID, android.permission.ACCESS_ADSERVICES_ATTRIBUTION, android.permission.ACCESS_ADSERVICES_AD_ID', 'Sensors Data Analytics': 'com.sensorsdata.analytics.android.sdk.data.SensorsDataContentProvider'}
# App 3rd party keyword:  ['Google Services', 'Advertising', 'Sensors Data Analytics']
# ------------------ Loop-71 ------------------
# App id:  net.workout.lose.weight.fitness.fit.coach
# App 3rd party:  {'Google Services': 'com.google.android.gms.permission.ACTIVITY_RECOGNITION, android.permission.ACTIVITY_RECOGNITION, com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.INSTANCE_ID_EVENT, com.google.android.gms.measurement.AppMeasurementReceiver, com.google.firebase.components', 'Advertising Services': 'com.google.android.gms.permission.AD_ID, android.permission.ACCESS_ADSERVICES_AD_ID', 'Intercom': 'io.intercom.android.sdk'}
# App 3rd party keyword:  ['Google Services', 'Advertising Services', 'Intercom']
# ------------------ Loop-72 ------------------
# App id:  dance.workout.home.fitness
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.measurement.AppMeasurementService', 'Facebook': 'com.facebook.sdk.ApplicationId, com.facebook.sdk.ClientToken', 'Advertising': 'com.google.android.gms.ads.APPLICATION_ID'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising']
# ------------------ Loop-73 ------------------
# App id:  com.fitnow.loseit
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.android.gms.measurement.AppMeasurementReceiver', 'Advertising Services': 'com.google.android.gms.ads.APPLICATION_ID', 'Samsung Health': 'Permissions for reading and writing various health data types', 'Firebase': 'Multiple Firebase components including Crashlytics, Analytics, and Installations'}
# App 3rd party keyword:  ['Google Services', 'Advertising Services', 'Samsung Health', 'Firebase']
# ------------------ Loop-74 ------------------
# App id:  com.starmax.runmefit
# App 3rd party:  {'Google': 'com.google.android.gms.permission.ACTIVITY_RECOGNITION, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.android.geo.API_KEY', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.sdk.ACTION_CURRENT_AUTHENTICATION_TOKEN_CHANGED, com.facebook.katana.provider.PlatformProvider, com.facebook.orca.provider.PlatformProvider, com.facebook.sdk.ApplicationId, com.facebook.sdk.ClientToken'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-75 ------------------
# App id:  com.runmifit.android
# App 3rd party:  {'Google': 'com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.android.geo.API_KEY, com.google.gms.fitness.sdk.version', 'Facebook': 'com.facebook.sdk.ApplicationId', 'Advertising and Analytics': 'MTA_APPKEY, MTA_CHANNEL, TA_APPKEY, Mob-AppKey'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising and Analytics']
# ------------------ Loop-76 ------------------
# App id:  com.orangetheoryfitness.orangetheory
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.permission.AD_ID', 'Zendesk': 'zendesk.support', 'Urban Airship': 'com.urbanairship.autopilot'}
# App 3rd party keyword:  ['Google Services', 'Zendesk', 'Urban Airship']
# ------------------ Loop-77 ------------------
# App id:  digifit.android.virtuagym.pro.greaterjolietymcasuperclub
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.measurement.AppMeasurementService, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.android.gms.cast.framework, com.google.mlkit'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-78 ------------------
# App id:  com.fitonomy.muscle.man
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.ads.MobileAdsInitProvider, com.google.firebase.perf.provider.FirebasePerfProvider, com.google.firebase.provider.FirebaseInitProvider', 'Facebook': 'com.facebook.FacebookContentProvider, com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED', 'Advertising': 'com.google.android.gms.ads.APPLICATION_ID, com.facebook.ads.internal.ipc.AdsProcessPriorityService'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising']
# ------------------ Loop-79 ------------------
# App id:  fitness.home.workout.weight.loss
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.measurement.AppMeasurementService, com.google.firebase.provider.FirebaseInitProvider', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.internal.FacebookInitProvider', 'Advertising': 'android.permission.ACCESS_ADSERVICES_ATTRIBUTION, android.permission.ACCESS_ADSERVICES_AD_ID'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising']
# ------------------ Loop-80 ------------------
# App id:  app.growwithjo.diet.fitness
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.measurement.AppMeasurementReceiver', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-81 ------------------
# App id:  ee.myfitness.app
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, firebase_crashlytics_collection_enabled, com.google.firebase.crashlytics.CrashlyticsRegistrar, com.google.android.gms.permission.AD_ID, com.google.android.gms.version'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-82 ------------------
# App id:  digifit.android.virtuagym.pro.xsportfitness
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.cast.framework, com.google.android.gms.analytics, com.google.android.gms.auth.api.signin, com.google.android.gms.measurement', 'Firebase Services': 'FirebasePerfRegistrar, FirebaseMessagingRegistrar, FirebaseCrashlyticsRegistrar', 'Google ML Kit': 'com.google.mlkit.common.internal.MlKitInitProvider'}
# App 3rd party keyword:  ['Google Services', 'Firebase Services', 'Google ML Kit']
# ------------------ Loop-83 ------------------
# App id:  com.bickster.fitbitbandfinder
# App 3rd party:  {'Google Services': 'com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.analytics.AnalyticsReceiver, AnalyticsService', 'Advertising': 'com.google.android.gms.permission.AD_ID, android.permission.ACCESS_ADSERVICES_AD_ID'}
# App 3rd party keyword:  ['Google Services', 'Advertising']
# ------------------ Loop-84 ------------------
# App id:  com.netpulse.mobile.muvfitness
# App 3rd party:  {'Google Services': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.measurement.AppMeasurementReceiver, com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.provider.FirebaseInitProvider', 'Advertising Services': 'android.permission.ACCESS_ADSERVICES_ATTRIBUTION, android.permission.ACCESS_ADSERVICES_AD_ID', 'Sentry': 'io.sentry.android.core.SentryInitProvider, io.sentry.android.core.SentryPerformanceProvider', 'Branch SDK': 'io.branch.sdk.BranchKey, io.branch.sdk.BranchKey.test'}
# App 3rd party keyword:  ['Google Services', 'Advertising Services', 'Sentry', 'Branch SDK']
# ------------------ Loop-85 ------------------
# App id:  com.fitifyapps.bwcardio
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.measurement.AppMeasurementService', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.internal.FacebookInitProvider', 'Advertising': 'com.google.android.gms.permission.AD_ID, android.permission.ACCESS_ADSERVICES_AD_ID'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising']
# ------------------ Loop-86 ------------------
# App id:  coach.zing.fitness
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.permission.AD_ID, android.permission.ACCESS_ADSERVICES_AD_ID', 'Advertising': 'com.google.android.gms.permission.AD_ID, android.permission.ACCESS_ADSERVICES_AD_ID', 'Braze': 'com.braze.push.BrazePushReceiver, com.braze.push.BrazeFirebaseMessagingService'}
# App 3rd party keyword:  ['Google Services', 'Advertising', 'Braze']
# ------------------ Loop-87 ------------------
# App id:  com.bottegasol.com.migym.fitnessconnection
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.measurement.AppMeasurementService, com.google.mlkit.common.internal.MlKitInitProvider', 'Advertising': 'com.google.android.gms.permission.AD_ID, android.permission.ACCESS_ADSERVICES_AD_ID', 'Sentry': 'io.sentry.android.core.SentryInitProvider, io.sentry.android.core.SentryPerformanceProvider'}
# App 3rd party keyword:  ['Google Services', 'Advertising', 'Sentry']
# ------------------ Loop-88 ------------------
# App id:  com.netpulse.mobile.chuzefitness
# App 3rd party:  {'Google Services': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.measurement.AppMeasurementService, com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.provider.FirebaseInitProvider', 'Advertising Services': 'android.permission.ACCESS_ADSERVICES_ATTRIBUTION, android.permission.ACCESS_ADSERVICES_AD_ID', 'Sentry': 'io.sentry.android.core.SentryInitProvider, io.sentry.android.core.SentryPerformanceProvider', 'Samsung Health': 'com.samsung.android.health.permission.read, com.samsung.android.health.permission.write', 'Branch.io': 'io.branch.sdk.BranchKey'}
# App 3rd party keyword:  ['Google Services', 'Advertising Services', 'Sentry', 'Samsung Health', 'Branch.io']
# ------------------ Loop-89 ------------------
# App id:  net.workoutinc.seven_7minutesfitness_forwomen
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.android.gms.permission.AD_ID, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.ads.MobileAdsInitProvider', 'Firebase Services': 'com.google.firebase.components:io.flutter.plugins.firebase.analytics.FlutterFirebaseAppRegistrar', 'Advertising Services': 'com.google.android.gms.ads.APPLICATION_ID'}
# App 3rd party keyword:  ['Google Services', 'Firebase Services', 'Advertising Services']
# ------------------ Loop-90 ------------------
# App id:  com.eightfit.app
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.android.gms.permission.AD_ID, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.auth.api.signin.RevocationBoundService', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-91 ------------------
# App id:  com.vt.vitafit
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.firebase.auth.api.gms.service.START, com.google.firebase.auth.api.fallback.service.FirebaseAuthFallbackService, com.google.firebase.components.ComponentDiscoveryService, com.google.firebase.provider.FirebaseInitProvider', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.sdk.ACTION_CURRENT_AUTHENTICATION_TOKEN_CHANGED, com.facebook.FacebookContentProvider, com.facebook.internal.FacebookInitProvider', 'Amazon': 'com.amazonaws.mobileconnectors.s3.transferutility.TransferService', 'Twitter': 'com.twitter.sdk.android.tweetcomposer.UPLOAD_SUCCESS, com.twitter.sdk.android.tweetcomposer.UPLOAD_FAILURE'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Amazon', 'Twitter']
# ------------------ Loop-92 ------------------
# App id:  com.mz.fit
# App 3rd party:  {'Google': 'com.google.android.gms.version, com.google.gms.fitness.sdk.version, com.google.android.gms.auth.api.signin.RevocationBoundService', 'AMap': 'com.amap.api.v2.apikey'}
# App 3rd party keyword:  ['Google', 'AMap']
# ------------------ Loop-93 ------------------
# App id:  com.bendingspoons.thirtydayfitness
# App 3rd party:  {'Google Services': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.ads.MobileAdsInitProvider, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.measurement.AppMeasurementService', 'Firebase': 'com.google.firebase.components.ComponentDiscoveryService, com.google.firebase.crashlytics.FirebaseCrashlyticsKtxRegistrar', 'Advertising': 'com.google.android.gms.ads.APPLICATION_ID, com.google.android.gms.ads.AD_MANAGER_APP'}
# App 3rd party keyword:  ['Google Services', 'Firebase', 'Advertising']
# ------------------ Loop-94 ------------------
# App id:  com.qingniu.feelfit
# ...
# App 3rd party keyword:  ['Google Services', 'Advertising']
# ------------------ Loop-404 ------------------
# App id:  it.evolutionfit.evolutionfit.club
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, firebase_analytics_collection_enabled, com.google.android.gms.measurement.AppMeasurementService, firebase_performance_collection_enabled, firebase_crashlytics_collection_enabled, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.android.gms.tagmanager.TagManagerService'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-405 ------------------
# App id:  com.user.livefitt
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.firebase.analytics.connector.internal.AnalyticsConnectorRegistrar', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-406 ------------------
# App id:  com.fitmind
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.firebase.provider.FirebaseInitProvider, com.google.firebase.components:com.google.firebase.crashlytics.CrashlyticsRegistrar', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.internal.FacebookInitProvider'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-407 ------------------
# App id:  fitness.fitprosport
# App 3rd party:  {'Google': 'com.android.vending.BILLING, com.google.android.play.billingclient.version, com.google.android.gms.version'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-408 ------------------
# App id:  com.yc.gloryfitpro
# App 3rd party:  {'Google': 'com.google.android.maps, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.gms.fitness.sdk.version, com.google.android.gms.permission.AD_ID', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.sdk.ACTION_CURRENT_AUTHENTICATION_TOKEN_CHANGED, com.facebook.FacebookContentProvider'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-409 ------------------
# App id:  com.zjw.xwfit
# App 3rd party:  {'Google': 'com.google.android.gms.version, com.google.android.gms.auth.api.signin.RevocationBoundService'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-410 ------------------
# App id:  com.step.walking.fit
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.ads.AdService, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.measurement.AppMeasurementService, AppMeasurementReceiver', 'Facebook': 'com.facebook.ads.AudienceNetworkContentProvider', 'AppLovin': 'com.applovin.sdk.AppLovinInitProvider', 'IronSource': 'com.ironsource.lifecycle.IronsourceLifecycleProvider', 'Vungle': 'com.vungle.warren.utility.VungleProvider', 'Bigo Ads': 'sg.bigo.ads.controller.provider.BigoAdsProvider', 'Adjoe': 'io.adjoe.sdk'}
# App 3rd party keyword:  ['Google', 'Facebook', 'AppLovin', 'IronSource', 'Vungle', 'Bigo Ads', 'Adjoe']
# ------------------ Loop-411 ------------------
# App id:  com.lianhezhuli.hyfit
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.gms.ads.AdService, com.google.firebase.provider.FirebaseInitProvider', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED, com.facebook.ads.AudienceNetworkContentProvider', 'AppLovin': 'com.applovin.sdk.AppLovinInitProvider'}
# App 3rd party keyword:  ['Google', 'Facebook', 'AppLovin']
# ------------------ Loop-412 ------------------
# App id:  com.fitworkout.lossweight.homeworkout.fitnessapp
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.ads.MobileAdsInitProvider, com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, com.google.firebase.provider.FirebaseInitProvider', 'Facebook': 'com.facebook.ads.AudienceNetworkContentProvider, com.facebook.sdk.ApplicationId', 'Advertising': 'android.permission.ACCESS_ADSERVICES_ATTRIBUTION'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising']
# ------------------ Loop-413 ------------------
# App id:  com.women.work.out.fit
# App 3rd party:  {'Google': 'com.google.android.gms.permission.AD_ID, com.google.android.gms.measurement.AppMeasurementReceiver, com.google.firebase.MESSAGING_EVENT, com.google.android.c2dm.permission.RECEIVE, com.google.firebase.provider.FirebaseInitProvider', 'AppLovin': 'com.applovin.sdk.AppLovinInitProvider, applovin.sdk.key', 'Smaato': 'com.smaato.sdk.core.lifecycle.ProcessLifecycleOwnerInitializer', 'IronSource': 'com.ironsource.lifecycle.IronsourceLifecycleProvider'}
# App 3rd party keyword:  ['Google', 'AppLovin', 'Smaato', 'IronSource']
# ------------------ Loop-414 ------------------
# App id:  com.jp.fitness.biceps.exrcise
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.android.gms.permission.AD_ID', 'Flurry': 'com.flurry.android.agent.FlurryContentProvider'}
# App 3rd party keyword:  ['Google Services', 'Flurry']
# ------------------ Loop-415 ------------------
# App id:  com.o2fitt
# App 3rd party:  {'Firebase Cloud Messaging': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService', 'Google Analytics': 'firebase_analytics_collection_enabled, google_analytics_adid_collection_enabled', 'Google ML Kit': 'com.google.mlkit.common.internal.MlKitInitProvider', 'Google Play Services': 'com.google.android.gms.measurement.AppMeasurementService', 'Advertising Services': 'com.google.android.gms.permission.AD_ID'}
# App 3rd party keyword:  ['Firebase Cloud Messaging', 'Google Analytics', 'Google ML Kit', 'Google Play Services', 'Advertising Services']
# ------------------ Loop-416 ------------------
# App id:  com.fitness.hiit.fat.burning.workout.jian032aplus
# App 3rd party:  {'Google': 'com.google.android.gms.ads.MobileAdsInitProvider, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.measurement.AppMeasurementService, AppMeasurementJobService', 'Facebook': 'com.facebook.ads.AudienceNetworkContentProvider, com.facebook.internal.FacebookInitProvider', 'Advertising': 'com.vungle.warren.utility.VungleProvider, com.applovin.sdk.AppLovinInitProvider'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Advertising']
# ------------------ Loop-417 ------------------
# App id:  com.workout.women.hiit.female.fitness.jian062lite
# App 3rd party:  {'Google': 'com.google.android.gms.ads.MobileAdsInitProvider, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.measurement.AppMeasurementService', 'Facebook': 'com.facebook.internal.FacebookInitProvider', 'AppLovin': 'com.applovin.sdk.AppLovinInitProvider, com.applovin.impl.adview.activity.FullscreenAdService'}
# App 3rd party keyword:  ['Google', 'Facebook', 'AppLovin']
# ------------------ Loop-418 ------------------
# App id:  com.fitlab.spartan
# App 3rd party:  {'Google': 'com.google.firebase.provider.FirebaseInitProvider, com.google.firebase.components:io.flutter.plugins.firebase.firebaseremoteconfig.FlutterFirebaseAppRegistrar, com.android.vending.BILLING', 'Facebook': 'com.facebook.sdk.ApplicationId, com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-419 ------------------
# App id:  com.airofit_app
# App 3rd party:  {'Firebase': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.messaging.FirebaseMessagingService', 'Google Analytics': 'firebase_analytics_collection_enabled, google_analytics_adid_collection_enabled, google_analytics_ssaid_collection_enabled', 'Google Play Billing': 'com.android.vending.BILLING, com.google.android.play.billingclient.version', 'Crashlytics': 'io.invertase.firebase.crashlytics.ReactNativeFirebaseCrashlyticsInitProvider, firebase_crashlytics_collection_enabled'}
# App 3rd party keyword:  ['Firebase', 'Google Analytics', 'Google Play Billing', 'Crashlytics']
# ------------------ Loop-420 ------------------
# App id:  com.undersunfitness
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.android.vending.BILLING, com.google.firebase.messaging.FirebaseMessagingService, com.google.firebase.provider.FirebaseInitProvider, com.google.android.play.core.assetpacks.AssetPackExtractionService'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-421 ------------------
# App id:  com.cizotech.fit2flaunt
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.provider.FirebaseInitProvider, com.google.android.gms.auth.api.signin.RevocationBoundService, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.measurement.AppMeasurementService, com.google.android.gms.permission.AD_ID', 'Facebook': 'com.facebook.sdk.ApplicationId, com.facebook.sdk.ClientToken', 'Stripe': 'stripe-auth'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Stripe']
# ------------------ Loop-422 ------------------
# App id:  com.mycloudfitness.mycloudfitness
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.ads.MobileAdsInitProvider, com.google.firebase.perf.provider.FirebasePerfProvider, com.google.mlkit.common.internal.MlKitInitProvider, com.google.firebase.provider.FirebaseInitProvider', 'Advertising': 'com.google.android.gms.ads.AdService', 'Analytics and Crash Reporting': 'Firebase Analytics, Firebase Crashlytics'}
# App 3rd party keyword:  ['Google Services', 'Advertising', 'Analytics and Crash Reporting']
# ------------------ Loop-423 ------------------
# App id:  com.evlofitness
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.analytics.AnalyticsReceiver, com.google.android.gms.analytics.AnalyticsService, com.google.android.gms.measurement.AppMeasurementReceiver, com.google.android.gms.measurement.AppMeasurementService, com.google.android.gms.cast.framework', 'Amazon Services': 'com.amazon.inapp.purchasing.Permission.NOTIFY', 'Zendesk': 'zendesk.support', 'Sentry': 'io.sentry.android.core.SentryInitProvider', 'AppsFlyer': 'com.appsflyer.referrer.INSTALL_PROVIDER'}
# App 3rd party keyword:  ['Google Services', 'Amazon Services', 'Zendesk', 'Sentry', 'AppsFlyer']
# ------------------ Loop-424 ------------------
# App id:  com.kannergroup.fitnessculture
# App 3rd party:  {'Google': 'com.android.vending.BILLING, com.google.android.gms.version, com.google.android.play.billingclient.version'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-425 ------------------
# App id:  com.highfitnesslive
# App 3rd party:  {}
# App 3rd party keyword:  []
# ------------------ Loop-426 ------------------
# App id:  com.fitness22.meditation
# App 3rd party:  {'Google': 'com.google.android.gms.analytics.AnalyticsReceiver, com.google.android.gms.analytics.AnalyticsService, com.google.android.gms.analytics.CampaignTrackingService, com.google.android.gms.analytics.AnalyticsJobService', 'Facebook': 'com.facebook.internal.FacebookInitProvider', 'Crashlytics': 'com.crashlytics.android.CrashlyticsInitProvider'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Crashlytics']
# ------------------ Loop-427 ------------------
# App id:  kr.fitt.fmes
# App 3rd party:  {'Google': 'com.android.vending.BILLING, com.google.android.play.billingclient.version'}
# App 3rd party keyword:  ['Google']
# ------------------ Loop-428 ------------------
# App id:  com.fixfit_fitness.twa
# App 3rd party:  {}
# App 3rd party keyword:  []
# ------------------ Loop-429 ------------------
# App id:  com.arketa.jamiegfitness
# App 3rd party:  {'Firebase Cloud Messaging': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService', 'Google Services': 'com.google.android.gms.cast.framework, com.google.android.gms.auth.api.signin', 'Bugsnag': 'com.bugsnag.android.API_KEY', 'Stripe': 'stripesdk', 'Glide': 'com.bumptech.glide.integration.okhttp3.OkHttpGlideModule'}
# App 3rd party keyword:  ['Firebase Cloud Messaging', 'Google Services', 'Bugsnag', 'Stripe', 'Glide']
# ------------------ Loop-430 ------------------
# App id:  com.trainerize.grindafitness
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.android.gms.cast.framework, com.google.android.gms.auth.api.signin', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-431 ------------------
# App id:  com.pushpress.punchkingfitnesssunset
# App 3rd party:  {'Firebase Cloud Messaging': 'com.google.android.c2dm.permission.RECEIVE, com.google.android.c2dm.intent.RECEIVE', 'Firebase Analytics and Crashlytics': 'firebase_analytics_collection_enabled, firebase_crashlytics_collection_enabled', 'Google Services': 'com.google.android.gms.permission.AD_ID, com.google.firebase.messaging.FirebaseMessagingService', 'OneSignal': 'com.onesignal.FCMBroadcastReceiver, com.onesignal.SyncService', 'Stripe': 'stripe-auth, stripesdk'}
# App 3rd party keyword:  ['Firebase Cloud Messaging', 'Firebase Analytics and Crashlytics', 'Google Services', 'OneSignal', 'Stripe']
# ------------------ Loop-432 ------------------
# App id:  com.trainerize.outlawfitcamp
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.android.gms.cast.framework, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.measurement', 'Facebook': 'com.facebook.sdk, com.facebook.internal.FacebookInitProvider'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-433 ------------------
# App id:  com.groupnos.openfitapp
# App 3rd party:  {}
# App 3rd party keyword:  []
# ------------------ Loop-434 ------------------
# App id:  com.marianatek.cbfit
# App 3rd party:  {'Sentry': 'io.sentry.android.core.SentryInitProvider, io.sentry.android.core.SentryPerformanceProvider', 'Firebase Analytics': 'firebase_analytics_collection_enabled'}
# App 3rd party keyword:  ['Sentry', 'Firebase Analytics']
# ------------------ Loop-435 ------------------
# App id:  com.fitnessmobileapps.elevate35253
# App 3rd party:  {'Google Services': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.MESSAGING_EVENT, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.analytics.AnalyticsReceiver, com.google.android.gms.analytics.AnalyticsService, com.google.android.gms.measurement.AppMeasurementReceiver, AppMeasurementService, com.google.android.gms.permission.AD_ID', 'Flurry Analytics': 'com.flurry.android.agent.FlurryContentProvider'}
# App 3rd party keyword:  ['Google Services', 'Flurry Analytics']
# ------------------ Loop-436 ------------------
# App id:  com.trainerize.ufit12
# App 3rd party:  {'Google': 'com.google.android.c2dm.permission.RECEIVE, com.google.firebase.messaging.FirebaseMessagingService, com.google.android.gms.cast.framework, com.google.android.gms.auth.api.signin.RevocationBoundService', 'Facebook': 'com.facebook.sdk.ACTION_CURRENT_ACCESS_TOKEN_CHANGED'}
# App 3rd party keyword:  ['Google', 'Facebook']
# ------------------ Loop-437 ------------------
# App id:  com.huaweiband9fitnessappadvice.kantundev
# App 3rd party:  {'Google': 'com.google.firebase.MESSAGING_EVENT, com.google.android.gms.ads.MobileAdsInitProvider', 'Facebook': 'com.facebook.ads.AudienceNetworkContentProvider', 'Flurry': 'com.flurry.android.agent.FlurryContentProvider', 'Sentry': 'io.sentry.android.core.SentryPerformanceProvider'}
# App 3rd party keyword:  ['Google', 'Facebook', 'Flurry', 'Sentry']
