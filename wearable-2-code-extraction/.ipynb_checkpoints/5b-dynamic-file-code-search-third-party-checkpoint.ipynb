# %%
from pymongo import MongoClient
import re
import os
from typing import List, Dict, Any
import shutil

# %%
def connect_mongodb(uri,db_name, collection_name):
    # Connect to MongoDB 
    client = MongoClient(uri)
    
    # Select the database and collection
    db = client[db_name]
    collection = db[collection_name]
    
    return collection
def query_mongodb(collection, query, fields=None):
    """
    Queries the MongoDB collection and returns specific fields or all fields if no specific ones are provided.
    
    Args:
        collection: The MongoDB collection object.
        query (dict): The query to filter documents.
        fields (list): List of fields to return from the query. If None, all fields are returned.
    
    Returns:
        result: List of documents with the specified fields or all fields.
    """
    # If fields is None, return all fields
    if fields:
        # Return only the specified fields
        projection = {field: 1 for field in fields}
    else:
        # Return all fields
        projection = None
    
    # Perform the query
    result = collection.find(query, projection)
    
    # Convert the cursor to a list and return
    return list(result)

def create_directory_if_not_exists(directory_path):
    if not os.path.exists(directory_path):  # Check if the directory exists
        try:
            os.makedirs(directory_path)  # Create the directory
            return f"Directory '{directory_path}' has been created."
        except Exception as e:
            return f"Error creating directory: {e}"
    else:
        return f"Directory '{directory_path}' already exists."
# Function search file path that contain keywork
def find_files_with_keyword(directory, keyword):
    matching_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                    if keyword in content:
                        matching_files.append(file_path)
            except Exception as e:
                print(f"Error reading {file_path}: {e}")
    return matching_files
def get_third_party_keyword_data(collection) -> List[Dict[str, Any]]:
    """
    Retrieve documents containing non-empty 'third-party-keyword'.

    Args:
        collection (pymongo.collection.Collection): The MongoDB collection to query.

    Returns:
        List[Dict[str, Any]]: A list of documents containing '_id' and 'third-party-keyword'.
    """
    query = {
        "third-party-keyword": {"$exists": True, "$ne": {}}
    }
    projection = {
        "_id": 1,
        "third-party-keyword": 1
    }

    results = collection.find(query, projection)
    
    # Collect all matching documents
    data = []
    for doc in results:
        if isinstance(doc.get("third-party-keyword"), dict) and any(doc["third-party-keyword"].values()):
            data.append({
                "_id": doc["_id"],
                "third-party-keyword": doc["third-party-keyword"]
            })
    
    return data
def extract_keywords(data: Dict[str, List[str]]) -> List[str]:
    """
    Extract keywords from the given dictionary and return them as a list.

    Args:
        data (Dict[str, List[str]]): The dictionary containing keywords as keys.

    Returns:
        List[str]: A list of keywords from the dictionary.
    """
    return list(data.keys())
def extract_import_lib(import_string: str) -> str:
    """
    Extracts the X part from an import statement of the form: 'import X'.

    Args:
        import_string (str): The import statement string.

    Returns:
        str: The extracted X part.
    """
    pattern = r'^import\s+(.+)$'
    match = re.match(pattern, import_string)
    if match:
        return match.group(1)
    else:
        return None
def copy_file(file_path: str, destination_dir: str) -> None:
    """
    Copies a file to the specified destination directory. If a duplicate is found,
    it automatically renames the file by appending '-duplicate-N' before the extension.

    Args:
        file_path (str): The path of the file to be copied.
        destination_dir (str): The directory where the file will be copied to.

    Returns:
        None
    """
    # Check if the source file exists
    if not os.path.isfile(file_path):
        raise FileNotFoundError(f"The file '{file_path}' does not exist.")
    
    # Check if the destination directory exists, if not, create it
    if not os.path.exists(destination_dir):
        os.makedirs(destination_dir)
    
    # Extract the file name and extension from the file path
    file_name, file_extension = os.path.splitext(os.path.basename(file_path))
    
    # Generate the initial destination path
    destination_file_path = os.path.join(destination_dir, f"{file_name}{file_extension}")
    
    duplicate_count = 1
    
    # Automatically rename the file if it already exists
    while os.path.exists(destination_file_path):
        #print(f"Duplicate file found: '{destination_file_path}'")
        destination_file_path = os.path.join(destination_dir, f"{file_name}-duplicate-{duplicate_count}{file_extension}")
        duplicate_count += 1
    
    # Copy the file to the destination directory
    shutil.copy(file_path, destination_file_path)
    #print(f"File '{file_path}' successfully copied to '{destination_file_path}'.")

# %%
# mongoDB_uri = 'mongodb://192.168.1.14:27017'
# mongoDB_database = 'wearable-project' 
# mongoDB_collection = 'wearable-standalone'
# local
mongoDB_uri = 'mongodb://localhost:27017'
mongoDB_database = 'wearable-project' 
# stand-alone collection
# mongoDB_collection = 'wearable-standalone-02-04-2025'
# root_directory = r'E:\wearable-standalone-code-extraction'
# source_code_root_directory = r"E:\wearable-project-decompile-source\source-code-standalone"
# app collection
mongoDB_collection = 'wearable-app-02-04-2025'
root_directory = r'E:\wearable-app-code-extraction'
source_code_root_directory = r"E:\wearable-project-decompile-source\source-code-wearable"

# %%
# Connect to the MongoDB collection
collection = connect_mongodb(mongoDB_uri,mongoDB_database,mongoDB_collection)
# Fetch the specified fields only
result_data = get_third_party_keyword_data(collection)
print(len(result_data))
# print(result)
# Out:
# 428

# %%
for i in range(192, len(result_data)):
    print("------------------ Loop-"+str(i)+"------------------")
    data = result_data[i]
    app_id = data["_id"]
    print("app_id: ", app_id)
    # app_directory = source_code_root_directory+"\\"+app_id+"-java"
    app_directory = source_code_root_directory+"\\"+app_id+".apk"
    extract_code_directory = root_directory+"\\"+app_id
    create_directory_if_not_exists(extract_code_directory)
    # print("app_directory: ",app_directory)
    app_third_party = data["third-party-keyword"]
    # print("app_third_party_keyword: ",app_third_party)
    third_party_name_arr = extract_keywords(app_third_party)
    # print("third_party_name_arr: ",third_party_name_arr)
    for j in range(len(third_party_name_arr)):
        third_party_name = third_party_name_arr[j]
        third_party_directory = extract_code_directory+"\\"+third_party_name
        create_directory_if_not_exists(third_party_directory)
        # print("*********** Third-party: "+third_party_name+" ***********")
        # print("third_party_name: ",third_party_name)
        # print("third_party_directory :",third_party_directory)
        third_party_keyword_arr = app_third_party[third_party_name]
        # print("third_party_keyword_arr: ",third_party_keyword_arr)
        for x in range(len(third_party_keyword_arr)):
            keyword = third_party_keyword_arr[x]
            # print("==== Third-party-keyword: "+keyword+" ====")
            matching_files = find_files_with_keyword(app_directory, keyword)
            # print("We found "+ str(len(matching_files)) + " file with keyword")
            if(len(matching_files)>0):
                code_file_directory = third_party_directory+"\\"+extract_import_lib(keyword)
                create_directory_if_not_exists(code_file_directory)
                for y in range(len(matching_files)):
                    file_path = matching_files[y]
                    copy_file(file_path, code_file_directory)
    #     break
    # break
# Out:
# ------------------ Loop-192------------------
# app_id:  clubwise.com.fitsense
# ------------------ Loop-193------------------
# app_id:  com.netpulse.mobile.greenfit
# ------------------ Loop-194------------------
# app_id:  fitflex.workout.fitness.weight.gym.fat.training
# ------------------ Loop-195------------------
# app_id:  com.netpulse.mobile.maxxfitnessclubzz
# ------------------ Loop-196------------------
# app_id:  com.netpulse.mobile.uniquefit
# ------------------ Loop-197------------------
# app_id:  com.taskoob.fitHer.android
# ------------------ Loop-198------------------
# app_id:  rs.fastfit.app
# ------------------ Loop-199------------------
# app_id:  com.cavosmart.wofit
# ------------------ Loop-200------------------
# app_id:  com.netpulse.mobile.fitnessforten
# ------------------ Loop-201------------------
# app_id:  sweatybetty.com.fitness.app
# ------------------ Loop-202------------------
# app_id:  com.netpulse.mobile.fitzonedelutte
# ------------------ Loop-203------------------
# app_id:  com.netpulse.mobile.stevenashfitnessworldsportsclub
# ------------------ Loop-204------------------
# app_id:  app.MOVE.fitcoapp.net
# ------------------ Loop-205------------------
# app_id:  digifit.virtuagym.client.android
# ------------------ Loop-206------------------
# app_id:  com.netpulse.mobile.tenfitness
# ------------------ Loop-207------------------
# app_id:  com.hainofit.health
# ------------------ Loop-208------------------
# app_id:  com.WahooFitness.SYSTM
# ------------------ Loop-209------------------
# app_id:  com.innovatise.justfit
# ------------------ Loop-210------------------
# app_id:  app.mfit.personal
# ------------------ Loop-211------------------
# app_id:  com.mobifitness.nsfit104363
# ------------------ Loop-212------------------
# app_id:  com.forfit.mymediterranean
# ------------------ Loop-213------------------
# app_id:  com.netpulse.mobile.dallascowboysfitness
# ------------------ Loop-214------------------
# app_id:  com.justfit.ymove.affitlife
# ------------------ Loop-215------------------
# app_id:  home.fitness.challenge
# ------------------ Loop-216------------------
# app_id:  fit.remotecoach.fitin
# ------------------ Loop-217------------------
# app_id:  com.johnsonfitness.fitdisplay2
# ------------------ Loop-218------------------
# app_id:  com.squats.fittr
# ------------------ Loop-219------------------
# app_id:  digifit.android.virtuagym.pro.ymcapeninsulademo
# ------------------ Loop-220------------------
# app_id:  app.f4square.fitness
# ------------------ Loop-221------------------
# app_id:  ie.zappy.fennec.barbellqueenfitness
# ------------------ Loop-222------------------
# app_id:  digifit.android.virtuagym.pro.levelupgym
# ------------------ Loop-223------------------
# app_id:  digifit.android.virtuagym.pro.sparksport22
# ------------------ Loop-224------------------
# app_id:  app.fit.meet
# ------------------ Loop-225------------------
# app_id:  com.trainerize.fitlov
# ------------------ Loop-226------------------
# app_id:  digifit.android.virtuagym.pro.fisic
# ------------------ Loop-227------------------
# app_id:  digifit.android.virtuagym.pro.bigbootyclub
# ------------------ Loop-228------------------
# app_id:  com.crrepa.band.havefit
# ------------------ Loop-229------------------
# app_id:  com.netpulse.mobile.morefitness
# ------------------ Loop-230------------------
# app_id:  digifit.android.virtuagym.pro.californiagymsuperclub
# ------------------ Loop-231------------------
# app_id:  appnativo.navysportcenter.fitcoapp.net
# ------------------ Loop-232------------------
# app_id:  com.mc.amazfit1
# ------------------ Loop-233------------------
# app_id:  com.mypthub.colourfit
# ------------------ Loop-234------------------
# app_id:  com.pubu.dafit
# ------------------ Loop-235------------------
# app_id:  com.trainerize.dashfitness
# ------------------ Loop-236------------------
# app_id:  com.independence284.badassbodyfitnessx
# ------------------ Loop-237------------------
# app_id:  com.hitec.fitness
# ------------------ Loop-238------------------
# app_id:  eu.fitric.pregnancyworkout
# ------------------ Loop-239------------------
# app_id:  uk.co.fitness4less.app
# ------------------ Loop-240------------------
# app_id:  com.trainerize.fitness19bergenfield
# ------------------ Loop-241------------------
# app_id:  com.zewa.fit.pro
# ------------------ Loop-242------------------
# app_id:  com.inova.kea.inovafit
# ------------------ Loop-243------------------
# app_id:  com.gymshark.fitness
# ------------------ Loop-244------------------
# app_id:  fit.mude.app
# ------------------ Loop-245------------------
# app_id:  fit.cure.android
# ------------------ Loop-246------------------
# app_id:  com.netpulse.mobile.fitnessproject
# ------------------ Loop-247------------------
# app_id:  digifit.android.virtuagym.pro.leisureunitedsuperclub
# ------------------ Loop-248------------------
# app_id:  digifit.android.virtuagym.pro.everlast
# ------------------ Loop-249------------------
# app_id:  digifit.android.virtuagym.pro.yababethfit
# ------------------ Loop-250------------------
# app_id:  rs.abstract.fitpass
# ------------------ Loop-251------------------
# app_id:  com.cognifit.app
# ------------------ Loop-252------------------
# app_id:  com.vulsen.popfit
# ------------------ Loop-253------------------
# app_id:  digifit.android.virtuagym.pro.strongfitnesswinfield
# ------------------ Loop-254------------------
# app_id:  digifit.android.virtuagym.pro.healthyvitabybv
# ------------------ Loop-255------------------
# app_id:  com.netpulse.mobile.bodyplexfamilyfitness
# ------------------ Loop-256------------------
# app_id:  com.onefitstop.atora
# ------------------ Loop-257------------------
# app_id:  com.trainerize.yetifit
# ------------------ Loop-258------------------
# app_id:  app.EnForma.fitcoapp.net
# ------------------ Loop-259------------------
# app_id:  com.fitnow.challenges
# ------------------ Loop-260------------------
# app_id:  com.fitifyapps.bwstretching
# ------------------ Loop-261------------------
# app_id:  com.mattdoesfitness.morsia
# ------------------ Loop-262------------------
# app_id:  fit.hplus.hplusfit
# ------------------ Loop-263------------------
# app_id:  com.future.FitYou
# ------------------ Loop-264------------------
# app_id:  com.fitlog.fitlog
# ------------------ Loop-265------------------
# app_id:  verv.health.fitness.workout.weight.loss
# ------------------ Loop-266------------------
# app_id:  com.fitplanapp.fitplan
# ------------------ Loop-267------------------
# app_id:  com.mobifitness.bettadance342273
# ------------------ Loop-268------------------
# app_id:  com.qingniu.megafit
# ------------------ Loop-269------------------
# app_id:  eu.fitric.hourglass
# ------------------ Loop-270------------------
# app_id:  com.vivefit
# ------------------ Loop-271------------------
# app_id:  digifit.android.virtuagym.pro.puurpersonaltraining
# ------------------ Loop-272------------------
# app_id:  club.nfit
# ------------------ Loop-273------------------
# app_id:  com.trainerize.idahofitnessfactory
# ------------------ Loop-274------------------
# app_id:  com.mysports.branded.mcfit
# ------------------ Loop-275------------------
# app_id:  com.btfit
# ------------------ Loop-276------------------
# app_id:  com.perfectgym.perfectgymgo2.wellfitness
# ------------------ Loop-277------------------
# app_id:  com.eztech.fitness
# ------------------ Loop-278------------------
# app_id:  com.fitzeee.menworkout
# ------------------ Loop-279------------------
# app_id:  br.com.personalfitapp
# ------------------ Loop-280------------------
# app_id:  es.dreamfit.app
# ------------------ Loop-281------------------
# app_id:  com.vgfit.shefit
# ------------------ Loop-282------------------
# app_id:  com.itrack.xfit
# ------------------ Loop-283------------------
# app_id:  rebel.fitness
# ------------------ Loop-284------------------
# app_id:  de.fitplusint
# ------------------ Loop-285------------------
# app_id:  com.bejaofit.app
# ------------------ Loop-286------------------
# app_id:  com.chloeting.fitness
# ------------------ Loop-287------------------
# app_id:  com.app.cy.GsFiten
# ------------------ Loop-288------------------
# app_id:  com.perfectgym.perfectgymgo2.fitness247latinamerica
# ------------------ Loop-289------------------
# app_id:  br.com.w12.heyfit
# ------------------ Loop-290------------------
# app_id:  fitness.ddx.ddx_fitness
# ------------------ Loop-291------------------
# app_id:  tarlin.fitness.loseweight.belly.fem
# ------------------ Loop-292------------------
# app_id:  pl.fit.world
# ------------------ Loop-293------------------
# app_id:  com.techbull.fitolympia
# ------------------ Loop-294------------------
# app_id:  com.vgfit.gofitness
# ------------------ Loop-295------------------
# app_id:  com.fitnesses.fitticoin
# ------------------ Loop-296------------------
# app_id:  com.fiteniummobile
# ------------------ Loop-297------------------
# app_id:  com.tony.hifitpro
# ------------------ Loop-298------------------
# app_id:  com.marsathletic.android.macfit.app
# ------------------ Loop-299------------------
# app_id:  com.nordlane.app_fitclubfinland_fi
# ------------------ Loop-300------------------
# app_id:  com.joshua.hasfit
# ------------------ Loop-301------------------
# app_id:  com.fitifyworkouts.bodyweight.workoutapp
# ------------------ Loop-302------------------
# app_id:  com.megasys.profit
# ------------------ Loop-303------------------
# app_id:  br.com.w12.redfit
# ------------------ Loop-304------------------
# app_id:  com.kompanion.fitness.android
# ------------------ Loop-305------------------
# app_id:  club.skllzz.fitness
# ------------------ Loop-306------------------
# app_id:  com.fitnessapps.yogakidsworkouts
# ------------------ Loop-307------------------
# app_id:  com.onefitstop.bodyfittraining
# ------------------ Loop-308------------------
# app_id:  com.workout.fitness.exercise.loseweight.gymworkout
# ------------------ Loop-309------------------
# app_id:  com.fitnessmobileapps.f45training
# ------------------ Loop-310------------------
# app_id:  com.steppi.steppifitness
# ------------------ Loop-311------------------
# app_id:  br.com.fitastic.appaluno
# ------------------ Loop-312------------------
# app_id:  com.brooklynfitzone.app
# ------------------ Loop-313------------------
# app_id:  com.anytimefitness.anytimeworkouts
# ------------------ Loop-314------------------
# app_id:  com.myfitnesscoach
# ------------------ Loop-315------------------
# app_id:  com.fitnesspassport.androidapp
# ------------------ Loop-316------------------
# app_id:  com.fitze
# ------------------ Loop-317------------------
# app_id:  com.fitzeee.fitzeeerun
# ------------------ Loop-318------------------
# app_id:  com.innovatise.fitnesstimeleejam
# ------------------ Loop-319------------------
# app_id:  com.yomaster.workout.fitness.yoga.yogaworkout
# ------------------ Loop-320------------------
# app_id:  com.actofitSmartScale
# ------------------ Loop-321------------------
# app_id:  com.fitnessanny
# ------------------ Loop-322------------------
# app_id:  fitness.app.women.female.workout
# ------------------ Loop-323------------------
# app_id:  com.bpfit.bloodpressure.health
# ------------------ Loop-324------------------
# app_id:  org.fitrunner
# ------------------ Loop-325------------------
# app_id:  com.womenfitness.workoutbuddy.mea
# ------------------ Loop-326------------------
# app_id:  fit.trainiac.android.client
# ------------------ Loop-327------------------
# app_id:  scope.fitnessfirstmena
# ------------------ Loop-328------------------
# app_id:  fit.ketoindia.ketoindia
# ------------------ Loop-329------------------
# app_id:  com.yc.gtfit
# ------------------ Loop-330------------------
# app_id:  pedometer.stepcounter.fitnessapp.stepstracker
# ------------------ Loop-331------------------
# app_id:  rs.nonstopfitness
# ------------------ Loop-332------------------
# app_id:  me.cofit.ironman
# ------------------ Loop-333------------------
# app_id:  com.growfitter.fitkit
# ------------------ Loop-334------------------
# app_id:  com.mga.fitty
# ------------------ Loop-335------------------
# app_id:  com.onelap.fitness
# ------------------ Loop-336------------------
# app_id:  com.noisefit.focus
# ------------------ Loop-337------------------
# app_id:  com.fitwhey.app
# ------------------ Loop-338------------------
# app_id:  de.upmcmobile.fitnessraum
# ------------------ Loop-339------------------
# app_id:  com.earthjumper.myhomefit
# ------------------ Loop-340------------------
# app_id:  com.huawo.hawofit
# ------------------ Loop-341------------------
# app_id:  com.mcsaatchi.gmfit
# ------------------ Loop-342------------------
# app_id:  com.evolutionwellness.app.celebrityfitness
# ------------------ Loop-343------------------
# app_id:  com.fitness.homeworkout.fullbodyworkout.gymworkout
# ------------------ Loop-344------------------
# app_id:  com.fitonomy.health.fitness
# ------------------ Loop-345------------------
# app_id:  com.apep.fitapp
# ------------------ Loop-346------------------
# app_id:  br.com.mufitness.station.aluno
# ------------------ Loop-347------------------
# app_id:  com.dailyyoga.fitness.workout
# ------------------ Loop-348------------------
# app_id:  com.fitness.stepcounter.pedometer
# ------------------ Loop-349------------------
# app_id:  com.evolutionwellness.app.fitnessfirst
# ------------------ Loop-350------------------
# app_id:  com.qualitrain.fitness
# ------------------ Loop-351------------------
# app_id:  fit.cult.android
# ------------------ Loop-352------------------
# app_id:  com.rootberz.thirtydayfitchallenges
# ------------------ Loop-353------------------
# app_id:  com.fitapp.timerwodapp
# ------------------ Loop-354------------------
# app_id:  com.huawo.ufit
# ------------------ Loop-355------------------
# app_id:  jp.joyfit.joyfitappandroid
# ------------------ Loop-356------------------
# app_id:  com.zsmart.zmoofit
# ------------------ Loop-357------------------
# app_id:  fit.withu.flutter.withu
# ------------------ Loop-358------------------
# app_id:  com.healthfitnessnordic.gxbooking
# ------------------ Loop-359------------------
# app_id:  com.fitelo.android
# ------------------ Loop-360------------------
# app_id:  com.riversongfit.epoch
# ------------------ Loop-361------------------
# app_id:  com.zelpasfitnesswraps.getabiggerbootyin7minutesbuttocksworkoutathome
# ------------------ Loop-362------------------
# app_id:  senior.fitness.exercises.elderly
# ------------------ Loop-363------------------
# app_id:  com.cs.booty.fit.buttocks.workout
# ------------------ Loop-364------------------
# app_id:  com.sai.fitIndia
# ------------------ Loop-365------------------
# app_id:  com.aukey.fit.pro
# ------------------ Loop-366------------------
# app_id:  homeworkoutapp.homeworkout.fitness.workout.loseweight
# ------------------ Loop-367------------------
# app_id:  com.shapehq.fitnessworld
# ------------------ Loop-368------------------
# app_id:  today.upfit
# ------------------ Loop-369------------------
# app_id:  com.proyecto.easyfitmx
# ------------------ Loop-370------------------
# app_id:  com.proyecto.fit.tgcustom
# ------------------ Loop-371------------------
# app_id:  com.proyecto.fitup.tgcustom
# ------------------ Loop-372------------------
# app_id:  net.peater.fitlovers
# ------------------ Loop-373------------------
# app_id:  com.proyecto.beonefitnesssport.tgcustom
# ------------------ Loop-374------------------
# app_id:  com.health.bloodsugar.healthly.fit
# ------------------ Loop-375------------------
# app_id:  com.madarsoft.fitness
# ------------------ Loop-376------------------
# app_id:  com.fitnessmobileapps.orangetheoryfitness
# ------------------ Loop-377------------------
# app_id:  com.jawline.exercises.fitness
# ------------------ Loop-378------------------
# app_id:  com.maitu.maitufit
# ------------------ Loop-379------------------
# app_id:  it.tripix.buddyfit
# ------------------ Loop-380------------------
# app_id:  br.com.w12.skyfitapp
# ------------------ Loop-381------------------
# app_id:  com.netpulse.mobile.cleverfiteu
# ------------------ Loop-382------------------
# app_id:  com.alex.crockfit
# ------------------ Loop-383------------------
# app_id:  org.eson.getfit3
# ------------------ Loop-384------------------
# app_id:  com.alphapod.fitsifu.jordanyeoh
# ------------------ Loop-385------------------
# app_id:  com.lifetrons.lifetrons.app.fitness
# ------------------ Loop-386------------------
# app_id:  com.fittech.fasting.tracker
# ------------------ Loop-387------------------
# app_id:  kr.co.everyfit.fitness
# ------------------ Loop-388------------------
# app_id:  com.zeofit.like
# ------------------ Loop-389------------------
# app_id:  com.fitness.mybodymass.bmicalculator
# ------------------ Loop-390------------------
# app_id:  com.transformfitness
# ------------------ Loop-391------------------
# app_id:  com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer
# ------------------ Loop-392------------------
# app_id:  com.fitness24seven.app
# ------------------ Loop-393------------------
# app_id:  com.reset.reset_fitness
# ------------------ Loop-394------------------
# app_id:  de.myfitcoach.tim.mfc
# ------------------ Loop-395------------------
# app_id:  com.canyon.fit
# ------------------ Loop-396------------------
# app_id:  homeworkout.fitness.app
# ------------------ Loop-397------------------
# app_id:  it.evolutionfit.evolutionfit.club
# ------------------ Loop-398------------------
# app_id:  com.user.livefitt
# ------------------ Loop-399------------------
# app_id:  com.fitmind
# ------------------ Loop-400------------------
# app_id:  fitness.fitprosport
# ------------------ Loop-401------------------
# app_id:  com.yc.gloryfitpro
# ------------------ Loop-402------------------
# app_id:  com.zjw.xwfit
# ------------------ Loop-403------------------
# app_id:  com.step.walking.fit
# ------------------ Loop-404------------------
# app_id:  com.lianhezhuli.hyfit
# ------------------ Loop-405------------------
# app_id:  com.fitworkout.lossweight.homeworkout.fitnessapp
# ------------------ Loop-406------------------
# app_id:  com.women.work.out.fit
# ------------------ Loop-407------------------
# app_id:  com.jp.fitness.biceps.exrcise
# ------------------ Loop-408------------------
# app_id:  com.o2fitt
# ------------------ Loop-409------------------
# app_id:  com.fitness.hiit.fat.burning.workout.jian032aplus
# ------------------ Loop-410------------------
# app_id:  com.workout.women.hiit.female.fitness.jian062lite
# ------------------ Loop-411------------------
# app_id:  com.fitlab.spartan
# ------------------ Loop-412------------------
# app_id:  com.airofit_app
# ------------------ Loop-413------------------
# app_id:  com.undersunfitness
# ------------------ Loop-414------------------
# app_id:  com.cizotech.fit2flaunt
# ------------------ Loop-415------------------
# app_id:  com.mycloudfitness.mycloudfitness
# ------------------ Loop-416------------------
# app_id:  com.evlofitness
# ------------------ Loop-417------------------
# app_id:  com.kannergroup.fitnessculture
# ------------------ Loop-418------------------
# app_id:  com.fitness22.meditation
# ------------------ Loop-419------------------
# app_id:  kr.fitt.fmes
# ------------------ Loop-420------------------
# app_id:  com.arketa.jamiegfitness
# ------------------ Loop-421------------------
# app_id:  com.trainerize.grindafitness
# ------------------ Loop-422------------------
# app_id:  com.pushpress.punchkingfitnesssunset
# ------------------ Loop-423------------------
# app_id:  com.trainerize.outlawfitcamp
# ------------------ Loop-424------------------
# app_id:  com.marianatek.cbfit
# ------------------ Loop-425------------------
# app_id:  com.fitnessmobileapps.elevate35253
# ------------------ Loop-426------------------
# app_id:  com.trainerize.ufit12
# ------------------ Loop-427------------------
# app_id:  com.huaweiband9fitnessappadvice.kantundev
# Number of file contain keyword com.clevertap is: 152
# Files containing the keyword com.clevertap
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\a24me\groupcal\fcm\FCMReceiver.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\a24me\groupcal\managers\a.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\a24me\groupcal\managers\q5.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\a.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\b.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\c.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\CleverTapInstanceConfig.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\CTInboxStyleConfig.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\d.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\e.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\g.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\h.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\i.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\InAppNotificationActivity.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\j.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\k.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\l.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\m.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\n.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\o.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\p.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\q.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\r.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\s.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\t.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\customviews\CloseImageView.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\customviews\HorizontalSquareImageView.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\customviews\RectangleImageView.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\customviews\SquareImageView.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\displayunits\model\CleverTapDisplayUnit.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\displayunits\model\CleverTapDisplayUnitContent.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\gif\a.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\gif\b.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\gif\c.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\gif\d.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\gif\e.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\gif\GifImageView.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\A.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\B.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\c.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\CTInAppNotification.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\CTInAppNotificationButton.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\CTInAppNotificationMedia.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\d.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\e.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\f.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\g.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\h.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\i.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\j.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\k.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\l.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\m.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\n.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\o.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\p.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\q.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\r.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\s.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\t.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\u.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\x.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\y.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inapp\z.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\a.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\b.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\c.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\CTCarouselViewPager.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\CTInboxActivity.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\CTInboxMessage.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\CTInboxMessageContent.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\d.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\e.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\f.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\g.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\h.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\i.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\j.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\inbox\k.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\a.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\b.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\c.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\CTNotificationIntentService.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\CTPushNotificationReceiver.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\d.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\e.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\f.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\g.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\h.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\i.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\j.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\m.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\n.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\amp\CTBackgroundIntentService.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\amp\CTBackgroundJobService.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\fcm\b.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\fcm\c.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\fcm\CTFirebaseMessagingReceiver.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\fcm\d.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\fcm\FcmPushProvider.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\clevertap\android\sdk\pushnotification\work\CTFlushPushImpressionsWork.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\D3\j.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\D3\l.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\D3\m.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\D3\o.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\D3\z.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\e3\a.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\e3\b.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\e3\d.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\e3\e.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\e3\f.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\e3\g.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\e3\l.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\F3\a.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\F3\e.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\G3\a.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\I3\a.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\I3\c.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\J3\d.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\J3\f.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\K3\a.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\K3\b.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\L3\d.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\L3\e.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\M3\b.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\n3\a.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\n3\c.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\n3\e.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\n3\f.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\n3\g.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\o3\f.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\p3\b.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\p3\c.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\p3\e.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\p3\f.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\S3\a.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\S3\b.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\S3\f.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\S3\g.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\S3\h.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\S3\i.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\S3\j.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\S3\k.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\S3\l.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\S3\m.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\S3\n.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\S3\o.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\t3\k.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\t3\l.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\u3\a.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\u3\e.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\v3\e.java
# *********** Third Party Name Zendesk ***********
# third_party_name:  Zendesk
# third party value:  Zendesk related providers and receivers
# keyword_final:  ['com.zendesk']
# ===== Search Keyword com.zendesk =====
# search_key_word:  com.zendesk
# Number of file contain keyword com.zendesk is: 3
# Files containing the keyword com.zendesk
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\com\zendesk\service\ZendeskDateTypeAdapter.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\zendesk\belvedere\v.java
# E:\wearable-project-decompile-source\source-code-standalone\app.groupcal.www-java\zendesk\core\ZendeskApplicationModule.java
