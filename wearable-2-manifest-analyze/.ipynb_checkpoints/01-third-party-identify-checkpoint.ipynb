# %%
import os
import xml.etree.ElementTree as ET
from datetime import datetime
from pymongo import MongoClient
import json
from typing import Dict, Any, Union, List
from dotenv import load_dotenv
# Langchain load data
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders import DirectoryLoader
### LLMs - Langchain
import openai
from langchain_core.prompts import ChatPromptTemplate
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain.chat_models import init_chat_model
### Summary chain
from langchain.prompts import PromptTemplate, ChatPromptTemplate
from langchain.chains import LLMChain, MapReduceChain, load_summarize_chain
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
from langchain_community.document_loaders import TextLoader

# %%
def connect_mongodb(uri,db_name, collection_name):
    # Connect to MongoDB 
    client = MongoClient(uri)
    
    # Select the database and collection
    db = client[db_name]
    collection = db[collection_name]
    
    return collection
def get_all_ids(collection):
    # Retrieve all _id values
    ids = collection.find({}, {"_id": 1})
    
    # Extract _id values into a list
    id_list = [doc["_id"] for doc in ids]
    
    return id_list
def get_ids_with_privacy_compliance(collection):
    # Query for documents that contain the "privacy-compliance" field
    docs = collection.find({"privacy-compliance": {"$exists": True}}, {"_id": 1})
    
    # Extract and return the list of _id values
    return [doc["_id"] for doc in docs]
def remove_common_elements(list_1, list_2):
    return [item for item in list_1 if item not in list_2]
def get_element_by_id(collection, id_value):
    # Find the document with the given _id
    result = collection.find_one({"_id": id_value})
    return result
def create_third_party_prompt(app_id,
                              app_tag_meta_data,
                              app_tag_action,
                              app_tag_application,
                              app_tag_data,
                              app_tag_property,
                              app_tag_provider,
                              app_tag_receiver,
                              app_tag_service,
                              app_tag_uses_configuration,
                              app_tag_uses_feature,
                              app_tag_uses_library):
    
    template = """
The app with the package name `{app_id}` is configured with the following manifest tags:
- Tag meta-data with attributes: {app_tag_meta_data}
- Tag action with attributes: {app_tag_action}
- Tag application with attributes: {app_tag_application}
- Tag data with attributes: {app_tag_data}
- Tag property with attributes: {app_tag_property}
- Tag provider with attributes: {app_tag_provider}
- Tag receiver with attributes: {app_tag_receiver}
- Tag service with attributes: {app_tag_service}
- Tag uses_configuration with attributes: {app_tag_uses_configuration}
- Tag uses_feature with attributes: {app_tag_uses_feature}
- Tag uses_library with attributes: {app_tag_uses_library}

Based on the above configuration, identify:
1. The third-party services that the app integrates with.
2. A list of corresponding import statements for each third-party service.

Respond in JSON format using one of the following examples:
- Case 1: suppose the app integrates with Google Firebase and Facebook
{{
    "Google Firebase": [
        "import com.google.firebase.messaging.FirebaseMessagingService",
        "import com.google.firebase.messaging.RemoteMessage"
    ],
    "Facebook": [
        "import com.facebook.FacebookSdk",
        "import com.facebook.appevents.AppEventsLogger"
    ]
}}

- Case 2: suppose the app does not integrate with any third-party service
{{
    "keyword": []
}}
Response with JSON structure only, don't add any explanation.
"""
    prompt = PromptTemplate.from_template(template)

    return prompt.format(
        app_id=app_id,
        app_tag_meta_data=app_tag_meta_data,
        app_tag_action=app_tag_action,
        app_tag_application=app_tag_application,
        app_tag_data=app_tag_data,
        app_tag_property=app_tag_property,
        app_tag_provider=app_tag_provider,
        app_tag_receiver=app_tag_receiver,
        app_tag_service=app_tag_service,
        app_tag_uses_configuration=app_tag_uses_configuration,
        app_tag_uses_feature=app_tag_uses_feature,
        app_tag_uses_library=app_tag_uses_library
    )
def extract_output_text_as_dict(response):
    """
    Extracts the 'output_text' from the response, cleans it, and converts it into a dictionary.

    :param response: The response dictionary containing 'output_text'.
    :return: A dictionary parsed from the 'output_text', or an empty dict if parsing fails.
    """
    if not response or not hasattr(response, "content"):  # Ensure response is valid
        print("Error: Invalid response object.")
        return {}

    output_text = response.content  # Assuming response.content holds the JSON string

    # Remove code block markers (```json and ```) if present
    if output_text.startswith("```json"):
        output_text = output_text[len("```json"):].strip("`").strip()

    try:
        # Convert the cleaned JSON string into a dictionary
        output_dict = json.loads(output_text)
        return output_dict
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        return {}  # Return an empty dictionary instead of None
def insert_third_party_data(collection, condition_value: str, data: Dict[str, list]):
    """
    Insert or update the given dictionary data into MongoDB under the field 'keyword' using _id as condition.

    Args:
        collection (pymongo.collection.Collection): The MongoDB collection to interact with.
        condition_value (str): The _id value to use as a condition for insertion.
        data (Dict[str, list]): The dictionary data to insert or update.

    Returns:
        pymongo.results.UpdateResult: The result of the MongoDB update operation.
    """
    filter_query = {"_id": condition_value}
    update_query = {"$set": {"third-party-keyword": data}}
    
    # Insert or update the document using upsert=True
    result = collection.update_one(filter_query, update_query, upsert=True)
    return result

# %%
directory_path = r"C:\Users\ASUS\anaconda3-project-code\wearable-apk-manifest\manifest-wearable"
log_file = "analyzed-manifest-project-2.log"

# %%
mongoDB_uri = 'mongodb://localhost:27017'
mongoDB_database_1 = 'wearable-project' 
mongoDB_collection_1 = 'wearable-app-02-04-2025'
# mongoDB_database_2 = 'wearable-project-2' 
# mongoDB_collection_2 = 'wearable-app'

# %%
collection_1 = connect_mongodb(mongoDB_uri, mongoDB_database_1, mongoDB_collection_1)
all_app_id = get_all_ids(collection_1)
print(len(all_app_id))
# Out:
# 5162

# %%
analyzed_app_id = get_ids_with_privacy_compliance(collection_1)
print(len(analyzed_app_id))
# Out:
# 641

# %%
final_app_id = remove_common_elements(all_app_id, analyzed_app_id)
print(len(final_app_id))
# Out:
# 4521

# %%
#. Chat model
# Setup model
# Load environment variables
load_dotenv()

# Retrieve API key
api_key = os.getenv("OPENAI_API_KEY")
# Ensure the API key is correctly set
if not api_key:
    raise ValueError("OPENAI_API_KEY is not set in the environment variables")

# Initialize the ChatOpenAI model
llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0,
    openai_api_key=api_key  # Ensure you explicitly pass the API key
)

# %%
for i in range(2805,len(final_app_id)):
    print("----------------------- Loop "+str(i)+" -----------------------")
    app_id = final_app_id[i]
    print("App id: ", app_id)
    app_data = get_element_by_id(collection_1,app_id)
    # app_tag_meta_data = app_data["tag-meta-data"]
    # app_tag_action = app_data["tag-action"]
    # app_tag_application = app_data["tag-application"]
    # app_tag_data = app_data["tag-data"]
    # app_tag_property = app_data["tag-property"]
    # app_tag_provider = app_data["tag-provider"]
    # app_tag_receiver = app_data["tag-receiver"]
    # app_tag_service = app_data["tag-service"]
    # app_tag_uses_configuration = app_data["tag-uses-configuration"]
    # app_tag_uses_feature = app_data["tag-uses-feature"]
    # app_tag_uses_library = app_data["tag-uses-library"]
    app_tag_meta_data = app_data.get("tag-meta-data", "not found")
    app_tag_action = app_data.get("tag-action", "not found")
    app_tag_application = app_data.get("tag-application", "not found")
    app_tag_data = app_data.get("tag-data", "not found")
    app_tag_property = app_data.get("tag-property", "not found")
    app_tag_provider = app_data.get("tag-provider", "not found")
    app_tag_receiver = app_data.get("tag-receiver", "not found")
    app_tag_service = app_data.get("tag-service", "not found")
    app_tag_uses_configuration = app_data.get("tag-uses-configuration", "not found")
    app_tag_uses_feature = app_data.get("tag-uses-feature", "not found")
    app_tag_uses_library = app_data.get("tag-uses-library", "not found")
    prompt_template = create_third_party_prompt(
            app_id,
            app_tag_meta_data,
            app_tag_action,
            app_tag_application,
            app_tag_data,
            app_tag_property,
            app_tag_provider,
            app_tag_receiver,
            app_tag_service,
            app_tag_uses_configuration,
            app_tag_uses_feature,
            app_tag_uses_library
    )
    # print(prompt_template)
    response = llm.invoke(prompt_template)
    # print(response.content)
    output_dict = extract_output_text_as_dict(response)
    # print(output_dict)
    insert_status = insert_third_party_data(collection_1,app_id,output_dict)
    print("insert_status: ", insert_status)
    # break
# Out:
# ----------------------- Loop 281 -----------------------
# App id:  de.j4velin.delayedlock2.trial
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 282 -----------------------
# App id:  rocketstartups.weardiceroller
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 283 -----------------------
# App id:  com.miruker.qcontact
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 284 -----------------------
# App id:  com.barkside.ipcam
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 285 -----------------------
# App id:  ch.publisheria.bring
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 286 -----------------------
# App id:  net.waynepiekarski.android.samples.opengl
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 287 -----------------------
# App id:  com.mydiabetes
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 288 -----------------------
# App id:  com.cuberob.weartasker
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 289 -----------------------
# App id:  mohammad.adib.wlock
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 290 -----------------------
# App id:  mobi.infolife.ezweather
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 291 -----------------------
# App id:  com.capitainetrain.android
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 292 -----------------------
# App id:  com.levelup.brightweather
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 293 -----------------------
# App id:  com.anddoes.notifier
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 294 -----------------------
# App id:  org.codechimp.qrwear
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 295 -----------------------
# App id:  hu.rycus.tweetwear
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 296 -----------------------
# App id:  com.rimidalv.dictaphone
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 297 -----------------------
# App id:  com.barkside.music
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 298 -----------------------
# App id:  net.micene.minigroup.workingtime
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 299 -----------------------
# App id:  com.appfour.wearbrowser
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 300 -----------------------
# App id:  ie.appz.dartwear
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 301 -----------------------
# App id:  com.notjust4time.coffeetimeforwear
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 302 -----------------------
# App id:  com.strava
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 303 -----------------------
# App id:  com.kochar.volumecontrol
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 304 -----------------------
# App id:  com.citymapper.app.release
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 305 -----------------------
# App id:  com.cafedered.praiasdegalicia
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 306 -----------------------
# App id:  com.banasiak.coinflip
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 307 -----------------------
# App id:  rocketstartups.wearflashlight
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 308 -----------------------
# App id:  com.abzdev.confcalldialerstd
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 309 -----------------------
# App id:  com.trello
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 310 -----------------------
# App id:  com.textmeinc.textme
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 311 -----------------------
# App id:  rocketstartups.wearcalculator
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 312 -----------------------
# App id:  com.delta.mobile.android
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 313 -----------------------
# App id:  com.wearablewidgets
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 314 -----------------------
# App id:  com.augmentra.viewranger.android
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 315 -----------------------
# App id:  com.google.android.keep
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 316 -----------------------
# App id:  com.businessslacks.ringremote
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 317 -----------------------
# App id:  com.zumper.rentals
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 318 -----------------------
# App id:  com.denite.watchface.diamondelegance
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 319 -----------------------
# App id:  com.bosenko.watchface.marinecommander
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 320 -----------------------
# App id:  com.healthyface.android.wearable.watchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 321 -----------------------
# App id:  com.kjsk.watchface.dogs
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 322 -----------------------
# App id:  com.denite.watchface.faceify
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 323 -----------------------
# App id:  huskydev.android.watchface.christmas2
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 324 -----------------------
# App id:  com.denite.watchface.carbongears
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 325 -----------------------
# App id:  com.denite.watchface.oreo
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 326 -----------------------
# App id:  de.freal.neonface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 327 -----------------------
# App id:  com.kjsk.watchface.city
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 328 -----------------------
# App id:  com.atektura.analogglowlitewatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 329 -----------------------
# App id:  com.denite.watchface.shockrreveal
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 330 -----------------------
# App id:  com.smartartstudios.digitalforcefree.interactive.watchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 331 -----------------------
# App id:  com.commandwear.android
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 332 -----------------------
# App id:  com.denite.watchface.meshreveal
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 333 -----------------------
# App id:  com.goonzmobile.wear.dx1watchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 334 -----------------------
# App id:  watch.richface.androidwear.valiant
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 335 -----------------------
# App id:  watch.richface.androidwear.armada2
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 336 -----------------------
# App id:  com.denite.watchface.digigears
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 337 -----------------------
# App id:  com.denite.watchface.dashinggears
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 338 -----------------------
# App id:  com.smartartstudios.extremefree.interactive.watchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 339 -----------------------
# App id:  me.fomand.nautiluswatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 340 -----------------------
# App id:  com.smartartstudios.halloweensfree.interactive.watchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 341 -----------------------
# App id:  com.smartartstudios.minimusfree.interactive.watchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 342 -----------------------
# App id:  com.smartartstudios.regal.interactive.wearnew.watchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 343 -----------------------
# App id:  com.denite.watchface.boldgears
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 344 -----------------------
# App id:  watch.richface.androidwear.timegate
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 345 -----------------------
# App id:  com.denite.watchface.meshgears
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 346 -----------------------
# App id:  com.denite.watchface.electroplasma
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 347 -----------------------
# App id:  com.denite.watchface.mechanigears
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 348 -----------------------
# App id:  com.zadocgames.watchfacerysilver
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 349 -----------------------
# App id:  com.sebcano.bewiwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 350 -----------------------
# App id:  com.denite.watchface.carbonfiber
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 351 -----------------------
# App id:  com.denite.watchface.facefx
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 352 -----------------------
# App id:  com.denite.watchface.woodengears
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 353 -----------------------
# App id:  com.kjsk.watchface.animatedabstract
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 354 -----------------------
# App id:  com.denite.watchface.faceie
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 355 -----------------------
# App id:  com.kjsk.watchface.sports
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 356 -----------------------
# App id:  com.denite.watchface.classyelegance
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 357 -----------------------
# App id:  com.denite.watchface.darkelegance
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 358 -----------------------
# App id:  com.watchlife.appdev.watchlife
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 359 -----------------------
# App id:  com.radefffactory.cleanwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 360 -----------------------
# App id:  com.magictools.pariswatch
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 361 -----------------------
# App id:  monte.morsewatch
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 362 -----------------------
# App id:  com.denite.watchface.timeracer
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 363 -----------------------
# App id:  com.kjsk.watchface.hindugod
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 364 -----------------------
# App id:  pifox.watchface.materialclock
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 365 -----------------------
# App id:  org.trypticon.android.love39watchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 366 -----------------------
# App id:  com.denite.watchface.darkshockr
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 367 -----------------------
# App id:  com.kjsk.watchface.jesus
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 368 -----------------------
# App id:  huskydev.android.watchface.photo
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 369 -----------------------
# App id:  com.paulserver.spacestarswatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 370 -----------------------
# App id:  watch.richface.androidwear.fury
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 371 -----------------------
# App id:  huskydev.android.watchface.info
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 372 -----------------------
# App id:  com.brohkahn.omegawatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 373 -----------------------
# App id:  com.denite.watchface.metallex
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 374 -----------------------
# App id:  com.denite.watchface.leathershockr
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 375 -----------------------
# App id:  com.denite.watchface.mysticspinner
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 376 -----------------------
# App id:  watch.richface.androidwear.digitalvision
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 377 -----------------------
# App id:  com.denite.watchface.brushedwood
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 378 -----------------------
# App id:  jp.ceres_inc.watch.app7
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 379 -----------------------
# App id:  com.kjsk.watchface.art
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 380 -----------------------
# App id:  com.kjsk.watchface.space
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 381 -----------------------
# App id:  com.kjsk.watchface.nature
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 382 -----------------------
# App id:  com.kjsk.watchface.love
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 383 -----------------------
# App id:  com.rimion.programmerswatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 384 -----------------------
# App id:  fun.droid.appwf.nation
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 385 -----------------------
# App id:  com.faltenreich.watchcraft
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 386 -----------------------
# App id:  net.loves8bit.qrclock
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 387 -----------------------
# App id:  com.fruit4droid.cronosurfsoccer
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 388 -----------------------
# App id:  com.whereismytrain.android
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 389 -----------------------
# App id:  com.stylingandroid.something.oclock
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 390 -----------------------
# App id:  com.peppyworks.starkwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 391 -----------------------
# App id:  jp.ceres_inc.watch.app1
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 392 -----------------------
# App id:  jp.ceres_inc.watch.app5
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 393 -----------------------
# App id:  com.denite.watchface.blackmetal2
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 394 -----------------------
# App id:  com.tbirkas.efflux
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 395 -----------------------
# App id:  com.sspai.cuto.android
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 396 -----------------------
# App id:  com.denite.watchface.galaxyglow
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 397 -----------------------
# App id:  com.watch.richface.smartdrive
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 398 -----------------------
# App id:  com.fruit4droid.cronosurf
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 399 -----------------------
# App id:  com.kjsk.watchface.watch1000
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 400 -----------------------
# App id:  com.moyinoluwa.yorubawatchfaces
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 401 -----------------------
# App id:  com.denite.watchface.simplefuzion
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 402 -----------------------
# App id:  com.watch.richface.guard
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 403 -----------------------
# App id:  huskydev.android.watchface.everydayfree
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 404 -----------------------
# App id:  com.gmail.maxdiland.firstwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 405 -----------------------
# App id:  com.denite.watchface.daringcarbon
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 406 -----------------------
# App id:  pl.brostudio.soccerlite
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 407 -----------------------
# App id:  com.denite.watchface.daringgraphite
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 408 -----------------------
# App id:  com.inductiveconcepts.wearable.mandalafaces
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 409 -----------------------
# App id:  fr.yochi376.glowwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 410 -----------------------
# App id:  com.github.premnirmal.patagonia
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 411 -----------------------
# App id:  com.teragon.koiwf
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 412 -----------------------
# App id:  droidnexustech.mursiwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 413 -----------------------
# App id:  com.denite.watchface.polishedstyle
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 414 -----------------------
# App id:  com.watch.richface.power
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 415 -----------------------
# App id:  co.slashware.pixelworldwatch
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 416 -----------------------
# App id:  huskydev.android.watchface.atlas
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 417 -----------------------
# App id:  com.denite.watchface.classicblack
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 418 -----------------------
# App id:  com.denite.watchface.classicwhite
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 419 -----------------------
# App id:  com.laurentiugh.watchface.tron
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 420 -----------------------
# App id:  com.denite.watchface.blackdarkness
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 421 -----------------------
# App id:  com.radefffactory.circlewatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 422 -----------------------
# App id:  dev.niamor.gaugewatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 423 -----------------------
# App id:  com.watch.richface.shield
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 424 -----------------------
# App id:  com.denite.watchface.brushedmetal
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 425 -----------------------
# App id:  com.imgur.timegur.watchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 426 -----------------------
# App id:  com.denite.watchface.blackleather
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 427 -----------------------
# App id:  jp.ceres_inc.watch.app4
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 428 -----------------------
# App id:  fr.yochi376.dotswatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 429 -----------------------
# App id:  com.denite.watchface.chromeled
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 430 -----------------------
# App id:  com.denite.watchface.brushedsilver
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 431 -----------------------
# App id:  com.altawatchface.collection
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 432 -----------------------
# App id:  com.denite.watchface.metalglow
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 433 -----------------------
# App id:  com.smd.studio.rugbywatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 434 -----------------------
# App id:  com.stepanov.orbitalwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 435 -----------------------
# App id:  com.radefffactory.whitewatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 436 -----------------------
# App id:  com.sparkistic.photowear
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 437 -----------------------
# App id:  com.denite.watchface.titaniumbrave
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 438 -----------------------
# App id:  com.androidlet.watchfacepix
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 439 -----------------------
# App id:  fr.yochi376.pictureswatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 440 -----------------------
# App id:  com.stealeks.colorwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 441 -----------------------
# App id:  com.denite.watchface.blackmetal
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 442 -----------------------
# App id:  com.mobimarketlabs.bonsai
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 443 -----------------------
# App id:  com.mobimarketlabs.clockster
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 444 -----------------------
# App id:  huskydev.android.watchface.classic
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 445 -----------------------
# App id:  com.tbs.bigtime.free
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 446 -----------------------
# App id:  com.plattysoft.ccwwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 447 -----------------------
# App id:  com.lob.lapseface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 448 -----------------------
# App id:  ca.rmen.nounours.lwp.robot
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 449 -----------------------
# App id:  wearablesoftware.wearwatchfacebuilder
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 450 -----------------------
# App id:  com.vuxia.WatchFaceCollection2016
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 451 -----------------------
# App id:  com.watch.richface.rolling
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 452 -----------------------
# App id:  com.pelmorex.WeatherEyeAndroid
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 453 -----------------------
# App id:  net.arkandroid.irkan.carbon_fiber_watch_face
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 454 -----------------------
# App id:  com.shashwat.android.wearable.watchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 455 -----------------------
# App id:  com.fossil.wearables.fossil
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 456 -----------------------
# App id:  com.devexpert.weather
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 457 -----------------------
# App id:  com.disney.starwarshub_goo
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 458 -----------------------
# App id:  com.radefffactory.scrollwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 459 -----------------------
# App id:  com.speedymarks.android.watch.colorwatch
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 460 -----------------------
# App id:  com.tagheuer.wear
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 461 -----------------------
# App id:  com.atektura.radialwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 462 -----------------------
# App id:  com.vuxia.wearFaceCollectionHD
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 463 -----------------------
# App id:  com.ammarptn.willow.digital.watch.face
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 464 -----------------------
# App id:  com.thehoodiestudio.halftimewatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 465 -----------------------
# App id:  info.fathom.watchfaces.isaac
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 466 -----------------------
# App id:  info.fathom.watchfaces.coubertin
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 467 -----------------------
# App id:  info.fathom.watchfaces.gaze
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 468 -----------------------
# App id:  de.appsonair.wallpaper.nyc.free
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 469 -----------------------
# App id:  com.dstvmobile.android
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 470 -----------------------
# App id:  com.codemybrainsout.boldwatch
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 471 -----------------------
# App id:  com.ustwo.watchfaces.bits
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 472 -----------------------
# App id:  jp.sfjp.gokigen.prpr0
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 473 -----------------------
# App id:  com.empty.digitalwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 474 -----------------------
# App id:  jp.ceres_inc.watch.app3
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 475 -----------------------
# App id:  com.mantrainfotek.blackbeautywearface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 476 -----------------------
# App id:  com.weareal.live
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 477 -----------------------
# App id:  dev.niamor.revolutionwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 478 -----------------------
# App id:  austinpatel.spectrumwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 479 -----------------------
# App id:  co.mobiwise.watchfacewater
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 480 -----------------------
# App id:  org.gdgph.watchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 481 -----------------------
# App id:  br.net.btco.curvaturewatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 482 -----------------------
# App id:  com.meowsbox.watchface01
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 483 -----------------------
# App id:  com.derfreimann.watchfaces.tinydoctors
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 484 -----------------------
# App id:  eu.stettiner.manyiconswatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 485 -----------------------
# App id:  com.microsoft.skydrive
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 486 -----------------------
# App id:  com.mikhaylov.kolesov.clockwidgets
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 487 -----------------------
# App id:  com.halachev.martin.android.wearable.chinesewatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 488 -----------------------
# App id:  com.bgpaglia.potawatch
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 489 -----------------------
# App id:  evos.zxspectime
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 490 -----------------------
# App id:  jp.gcreate.product.customphotowatch
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 491 -----------------------
# App id:  nowawatch.nowaweb.com.lunawatch
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 492 -----------------------
# App id:  ru.slobodchikov.kgbwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 493 -----------------------
# App id:  com.enzonium.flashlite
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 494 -----------------------
# App id:  com.ceressoftware.android.wear.paperfree
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 495 -----------------------
# App id:  com.crittermap.watchface.bluecarbon
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 496 -----------------------
# App id:  com.alexismorin.dotswatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 497 -----------------------
# App id:  watchface.lbriceno.com.binarynerd
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 498 -----------------------
# App id:  softdev.fribeiro.splitwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 499 -----------------------
# App id:  hu.rycus.watchface.stringtheory
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 500 -----------------------
# App id:  com.sweetlime.spiderwatch
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 501 -----------------------
# App id:  com.leonardogandini.circuswatchfaces
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 502 -----------------------
# App id:  eu.stettiner.warsawshorewatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 503 -----------------------
# App id:  eu.stettiner.diamondwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 504 -----------------------
# App id:  eu.stettiner.zigzagwatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 505 -----------------------
# App id:  com.halachev.martin.android.wearable.bizarrewatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 506 -----------------------
# App id:  com.halachev.martin.android.wearable.binarywatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 507 -----------------------
# App id:  com.goodpatch.android.watchface.moonwatch
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 508 -----------------------
# App id:  com.thehoodiestudio.mustachewatchface
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 509 -----------------------
# App id:  com.wjp.zombie
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 510 -----------------------
# App id:  com.jumia.android
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 511 -----------------------
# App id:  com.goodpatch.android.watchface.scanimation
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 512 -----------------------
# App id:  com.xlythe.clock.scene
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 513 -----------------------
# App id:  com.xlythe.clock.leaflet
# ...
# ----------------------- Loop 2799 -----------------------
# App id:  pl.oksystem
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 2800 -----------------------
# App id:  com.terappin
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 2801 -----------------------
# App id:  ro.worldclass.members
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 2802 -----------------------
# App id:  com.purpleteal.tweakandeat
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 2803 -----------------------
# App id:  com.cookware.weightlossrecipes
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 2804 -----------------------
# App id:  com.avanutri.mobile
# insert_status:  UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
# ----------------------- Loop 2805 -----------------------
# App id:  com.wattbike.powerapp
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 43
#      28 prompt_template = create_third_party_prompt(
#      29         app_id,
#      30         app_tag_meta_data,
#    (...)
#      40         app_tag_uses_library
#      41 )
#      42 # print(prompt_template)
# ---> 43 response = llm.invoke(prompt_template)
#      44 # print(response.content)
#      45 output_dict = extract_output_text_as_dict(response)
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\langchain_core\language_models\chat_models.py:307, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     296 def invoke(
#     297     self,
#     298     input: LanguageModelInput,
#    (...)
#     302     **kwargs: Any,
#     303 ) -> BaseMessage:
#     304     config = ensure_config(config)
#     305     return cast(
#     306         ChatGeneration,
# --> 307         self.generate_prompt(
#     308             [self._convert_input(input)],
#     309             stop=stop,
#     310             callbacks=config.get("callbacks"),
#     311             tags=config.get("tags"),
#     312             metadata=config.get("metadata"),
#     313             run_name=config.get("run_name"),
#     314             run_id=config.pop("run_id", None),
#     315             **kwargs,
#     316         ).generations[0][0],
#     317     ).message
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\langchain_core\language_models\chat_models.py:843, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     835 def generate_prompt(
#     836     self,
#     837     prompts: list[PromptValue],
#    (...)
#     840     **kwargs: Any,
#     841 ) -> LLMResult:
#     842     prompt_messages = [p.to_messages() for p in prompts]
# --> 843     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\langchain_core\language_models\chat_models.py:683, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     680 for i, m in enumerate(messages):
#     681     try:
#     682         results.append(
# --> 683             self._generate_with_cache(
#     684                 m,
#     685                 stop=stop,
#     686                 run_manager=run_managers[i] if run_managers else None,
#     687                 **kwargs,
#     688             )
#     689         )
#     690     except BaseException as e:
#     691         if run_managers:
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\langchain_core\language_models\chat_models.py:908, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     906 else:
#     907     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 908         result = self._generate(
#     909             messages, stop=stop, run_manager=run_manager, **kwargs
#     910         )
#     911     else:
#     912         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\langchain_openai\chat_models\base.py:823, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     821     generation_info = {"headers": dict(raw_response.headers)}
#     822 else:
# --> 823     response = self.client.create(**payload)
#     824 return self._create_chat_result(response, generation_info)
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\openai\resources\chat\completions\completions.py:879, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     837 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     838 def create(
#     839     self,
#    (...)
#     876     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     877 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     878     validate_response_format(response_format)
# --> 879     return self._post(
#     880         "/chat/completions",
#     881         body=maybe_transform(
#     882             {
#     883                 "messages": messages,
#     884                 "model": model,
#     885                 "audio": audio,
#     886                 "frequency_penalty": frequency_penalty,
#     887                 "function_call": function_call,
#     888                 "functions": functions,
#     889                 "logit_bias": logit_bias,
#     890                 "logprobs": logprobs,
#     891                 "max_completion_tokens": max_completion_tokens,
#     892                 "max_tokens": max_tokens,
#     893                 "metadata": metadata,
#     894                 "modalities": modalities,
#     895                 "n": n,
#     896                 "parallel_tool_calls": parallel_tool_calls,
#     897                 "prediction": prediction,
#     898                 "presence_penalty": presence_penalty,
#     899                 "reasoning_effort": reasoning_effort,
#     900                 "response_format": response_format,
#     901                 "seed": seed,
#     902                 "service_tier": service_tier,
#     903                 "stop": stop,
#     904                 "store": store,
#     905                 "stream": stream,
#     906                 "stream_options": stream_options,
#     907                 "temperature": temperature,
#     908                 "tool_choice": tool_choice,
#     909                 "tools": tools,
#     910                 "top_logprobs": top_logprobs,
#     911                 "top_p": top_p,
#     912                 "user": user,
#     913             },
#     914             completion_create_params.CompletionCreateParams,
#     915         ),
#     916         options=make_request_options(
#     917             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     918         ),
#     919         cast_to=ChatCompletion,
#     920         stream=stream or False,
#     921         stream_cls=Stream[ChatCompletionChunk],
#     922     )
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\openai\_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)
#    1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\openai\_base_client.py:919, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     916 else:
#     917     retries_taken = 0
# --> 919 return self._request(
#     920     cast_to=cast_to,
#     921     options=options,
#     922     stream=stream,
#     923     stream_cls=stream_cls,
#     924     retries_taken=retries_taken,
#     925 )
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\openai\_base_client.py:955, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     952 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     954 try:
# --> 955     response = self._client.send(
#     956         request,
#     957         stream=stream or self._should_stream_response_body(request=request),
#     958         **kwargs,
#     959     )
#     960 except httpx.TimeoutException as err:
#     961     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\anaconda3\envs\py310_env\lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~\anaconda3\envs\py310_env\lib\ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File ~\anaconda3\envs\py310_env\lib\ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
